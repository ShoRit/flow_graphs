# %%
from collections import Counter
import json

# %%
datasets = ["wsj", "risec", "japflow", "chemu", "mscorpus"]

# %%
semantics_dict = {}

for dataset in datasets:
    vn_classes = []
    vn_roles = []
    modifiers = []
    labels = []

    with open(f"/projects/flow_graphs/data/{dataset}/{dataset}_semantics.json") as f:
        dataset_sentences = json.load(f)

    for sentence in dataset_sentences:
        if sentence["annotations"] is None:
            continue
        for prop in sentence["annotations"]["props"]:
            vn_classes.append(prop["sense"])
            for span in prop["spans"]:
                if span["modifier"]:
                    modifiers.append(span["label"])
                elif span["predicate"]:
                    continue
                else:
                    vn_roles.append(span["vn"])
                    labels.append(span["label"])

    semantics_dict[dataset] = {
        "vn_classes": vn_classes,
        "vn_roles": vn_roles,
        "labels": labels,
        "n_sentences": len(dataset_sentences),
    }

# %%
stats_dict = {}
for dataset, dataset_dict in semantics_dict.items():
    stats_dict[dataset] = {
        k: Counter(v) for k, v in dataset_dict.items() if k != "n_sentences"
    }
    stats_dict[dataset]["n_sentences"] = dataset_dict["n_sentences"]

# %%
stats_dict
# Out:
# {'wsj': {'vn_classes': Counter({'mix-22.1-2-1': 221,
#            'seem-109-1-1': 11523,
#            'dub-29.3.2': 868,
#            'use-105.1': 764,
#            'build-26.1-1': 846,
#            'engender-27.1-1': 276,
#            'disappearance-48.2': 110,
#            'indicate-78': 173,
#            'say-37.7-1-1': 8676,
#            'escape-51.1-1-2': 91,
#            'reflexive_appearance-48.1.2': 442,
#            'indicate-78-1-1': 514,
#            'stop-55.4-1-1': 621,
#            'discover-84': 522,
#            'seem-109-1-1-1': 508,
#            'bring-11.3-1': 233,
#            'talk-37.5': 322,
#            'see-30.1-1-1-1': 93,
#            'own-100.1': 2209,
#            'learn-14-1': 289,
#            'accompany-51.7': 261,
#            'substitute-13.6.2-1': 103,
#            'give-13.1-1': 1587,
#            'cooperate-73.1-3': 299,
#            'admit-64.3-1': 736,
#            'admire-31.2': 658,
#            'battle-36.4': 623,
#            'get-13.5.1': 2339,
#            'characterize-29.2': 328,
#            'future_having-13.3': 1517,
#            'reject-77.2-1': 90,
#            'transfer_mesg-37.1.1': 303,
#            'enforce-63': 182,
#            'consume-66': 216,
#            'orphan-29.7': 18,
#            'funnel-9.3-1-1': 73,
#            'pour-9.5': 39,
#            'characterize-29.2-1-1': 421,
#            'put_spatial-9.2': 112,
#            'remedy-45.7': 240,
#            'interrogate-37.1.3': 245,
#            'comprehend-87.2-1': 66,
#            'occur-48.3': 40,
#            'continue-55.3': 417,
#            'slide-11.2-1': 22,
#            'wish-62': 1743,
#            'stalk-35.3': 38,
#            'characterize-29.2-1-2': 311,
#            'other_cos-45.4': 3056,
#            'adopt-93': 365,
#            'grow-26.2.1': 111,
#            'equip-13.4.2': 423,
#            'consider-29.9-2': 535,
#            'indicate-78-1': 161,
#            'allow-64.1-1': 286,
#            'consider-29.9-1-1-1': 330,
#            'steal-10.5-1': 65,
#            'assessment-34.1': 439,
#            'spatial_configuration-47.6': 175,
#            'calibratable_cos-45.6.1-1': 1883,
#            'sound_emission-43.2': 105,
#            'amalgamate-22.2-2': 606,
#            'differ-23.4': 77,
#            'escape-51.1-1': 831,
#            'acquiesce-95.1': 185,
#            'promote-102': 323,
#            'hold-15.1': 490,
#            'amuse-31.1': 2532,
#            'appoint-29.1': 376,
#            'succeed-74-1': 245,
#            'resign-10.11-1': 174,
#            'complete-55.2-1': 172,
#            'function-105.2.1-1': 487,
#            'base-97.1': 297,
#            'hire-13.5.3': 214,
#            'shake-22.3-2-1': 586,
#            'put_direction-9.4': 582,
#            'masquerade-29.6-1': 86,
#            'fulfilling-13.4.1': 237,
#            'battle-36.4-1': 160,
#            'caused_calibratable_cos-45.6.2': 207,
#            'separate-23.1-1': 230,
#            'vehicle-51.4.1': 8,
#            'lodge-46': 144,
#            'meet-36.3-1': 498,
#            'settle-36.1.2-1': 410,
#            'deduce-97.2': 98,
#            'run-51.3.2-2': 255,
#            'escape-51.1': 17,
#            'judgment-33.1-1': 335,
#            'forbid-64.4-1': 396,
#            'carry-11.4': 166,
#            'breathe-40.1.2': 7,
#            'wink-40.3.1': 95,
#            'concealment-16': 96,
#            'feeding-39.7': 28,
#            'comprehend-87.2-1-1-1': 504,
#            'eat-39.1-1': 30,
#            'give-13.1': 925,
#            'send-11.1': 609,
#            'rummage-35.5': 113,
#            'register-54.1-1-1': 195,
#            'focus-87.1-1': 203,
#            'free-10.6.3-1': 111,
#            'throw-17.1': 33,
#            'spatial_configuration-47.6-1': 201,
#            'caused_calibratable_cos-45.6.2-1': 697,
#            'begin-55.1-1-1': 908,
#            'transcribe-25.4': 113,
#            'try-61.1': 348,
#            'amalgamate-22.2-3-1': 179,
#            'sustain-55.6': 151,
#            'become-109.1-1-1': 389,
#            'fill-9.8': 375,
#            'cost-54.2': 547,
#            'fulfilling-13.4.1-1': 253,
#            'search-35.2': 228,
#            'equip-13.4.2-1': 131,
#            'exceed-90': 141,
#            'pay-68': 173,
#            'matter-91': 26,
#            'pay-68-1': 727,
#            'act-114-1': 657,
#            'get-13.5.1-1': 874,
#            'carve-21.2-1': 81,
#            'put-9.1-2': 703,
#            'benefit-72.2': 92,
#            'limit-76': 646,
#            'create-26.4': 1219,
#            'help-72.1-1-1': 445,
#            'require-103-1': 494,
#            'subordinate-95.2.1': 2,
#            'remove-10.1': 655,
#            'neglect-75.1-1': 163,
#            'patent-101': 121,
#            'exist-47.1': 595,
#            'confront-98': 361,
#            'defend-72.3': 326,
#            'entity_specific_cos-45.5': 117,
#            'hurt-40.8.3-2': 66,
#            'judgment-33.1-1-1': 35,
#            'chase-51.6': 181,
#            'establish-55.5-1': 586,
#            'illustrate-25.3': 135,
#            'compel-59.1': 125,
#            'performance-26.7': 130,
#            'consider-29.9-1': 26,
#            'conspire-71': 83,
#            'mix-22.1-1-1': 161,
#            'stimulate-59.4': 89,
#            'transfer_mesg-37.1.1-1-1': 368,
#            'create-26.4-1-1': 152,
#            'build-26.1': 433,
#            'lecture-37.11-1-1': 198,
#            'complain-37.8': 186,
#            'fulfilling-13.4.1-2': 423,
#            'urge-58.1-1-1': 300,
#            'remedy-45.7-1': 13,
#            'conjecture-29.5-1': 396,
#            'see-30.1-1-1': 712,
#            'want-32.1-1-1': 940,
#            'assuming_position-50': 141,
#            'register-54.1': 91,
#            'keep-15.2': 114,
#            'adjust-26.9': 130,
#            'drive-11.5': 76,
#            'contribute-13.2-1': 130,
#            'obtain-13.5.2-1': 595,
#            'render-29.90-1': 490,
#            'occur-48.3-1': 434,
#            'deprive-10.6.2': 43,
#            'chit_chat-37.6': 128,
#            'attend-107.4-2': 86,
#            'manner_speaking-37.3': 92,
#            'herd-47.5.2': 71,
#            'risk-94-1': 154,
#            'funnel-9.3-1': 15,
#            'equip-13.4.2-1-1': 66,
#            'correspond-36.1.1-1': 326,
#            'run-51.3.2-2-1': 335,
#            'pocket-9.10': 359,
#            'contiguous_location-47.8': 290,
#            'meander-47.7': 319,
#            'butter-9.9': 157,
#            'throw-17.1-1-1': 81,
#            'bump-18.4-1': 161,
#            'exchange-13.6.1': 302,
#            'peer-30.3': 246,
#            'meander-47.7-1': 184,
#            'convert-26.6.2-1': 119,
#            'run-51.3.2': 257,
#            'see-30.1-1': 57,
#            'hunt-35.1': 330,
#            'require-103': 67,
#            'price-54.4': 1333,
#            'caring-75.2-1-1': 67,
#            'roll-51.3.1': 128,
#            'spank-18.3': 17,
#            'tape-22.4': 133,
#            'say-37.7-1-1-1': 253,
#            'say-37.7-1': 865,
#            'advise-37.9-1': 243,
#            'escape-51.1-1-1': 98,
#            'clear-10.3-1': 52,
#            'allow-64.1': 160,
#            'obtain-13.5.2': 696,
#            'contribute-13.2-2': 33,
#            'succeed-74-3-1-1': 84,
#            'investigate-35.4': 407,
#            'learn-14-2-1': 28,
#            'turn-26.6.1-1': 150,
#            'lure-59.3': 136,
#            'split-23.2': 287,
#            'result-27.2': 108,
#            'pocket-9.10-1': 58,
#            'sight-30.2': 590,
#            'amalgamate-22.2-2-1': 74,
#            'multiply-108': 42,
#            'instr_communication-37.4.1': 62,
#            'mix-22.1-2': 255,
#            'estimate-34.2-1': 140,
#            'pit-10.7': 89,
#            'confess-37.10': 129,
#            'declare-29.4-1-1': 88,
#            'classify-29.10': 33,
#            'judgment-33.1': 65,
#            'amalgamate-22.2-1': 84,
#            'contribute-13.2-1-1': 427,
#            'declare-29.4-1-1-2': 47,
#            'eat-39.1-2': 29,
#            'marvel-31.3': 295,
#            'break-45.1': 176,
#            'marry-36.2': 58,
#            'scribble-25.2-1': 180,
#            'rummage-35.5-1': 13,
#            'avoid-52': 135,
#            'image_impression-25.1': 138,
#            'simple_dressing-41.3.1-1': 48,
#            'scribble-25.2': 78,
#            'contiguous_location-47.8-2': 59,
#            'fit-54.3': 141,
#            'break_down-45.8': 2,
#            'dedicate-79': 144,
#            'multiply-108-3': 205,
#            'play-114.2-1': 7,
#            'rely-70': 223,
#            'captain-29.8-1': 70,
#            'admire-31.2-1': 240,
#            'conduct-111.1': 120,
#            'let-64.2': 124,
#            'create-26.4-1': 61,
#            'fire-10.10': 120,
#            'discover-84-1-1': 37,
#            'bill-54.5': 198,
#            'eat-39.1-3': 5,
#            'linger-53.1-1': 112,
#            'cope-83': 228,
#            'flinch-40.5': 25,
#            'convert-26.6.2': 424,
#            'stop-55.4-1': 113,
#            'order-58.3-1': 106,
#            'destroy-44': 362,
#            'coloring-24': 31,
#            'amalgamate-22.2-3-1-1': 9,
#            'disappearance-48.2-1': 90,
#            'substitute-13.6.2': 25,
#            'supervision-95.2.2': 93,
#            'poison-42.2': 39,
#            'comprise-107.2-2': 36,
#            'performance-26.7-1': 193,
#            'preparing-26.3-1': 47,
#            'conjecture-29.5-2': 75,
#            'characterize-29.2-1': 188,
#            'push-12-1-1': 59,
#            'die-42.4-1': 28,
#            'coil-9.6-1': 15,
#            'consume-66-1': 98,
#            'animal_sounds-38': 9,
#            'free-10.6.3-1-1': 33,
#            'murder-42.1': 117,
#            'advise-37.9': 111,
#            'spray-9.7-2': 48,
#            'sound_existence-47.4': 22,
#            'succeed-74-1-1': 106,
#            'complete-55.2': 66,
#            'empathize-88.2': 14,
#            'cooperate-73.1-1': 25,
#            'murder-42.1-1': 106,
#            'carve-21.2-2': 17,
#            'chit_chat-37.6-1': 96,
#            'invest-13.5.4': 72,
#            'harmonize-22.6': 41,
#            'reach-51.8': 67,
#            'spray-9.7-1': 130,
#            'attack-60.1-1': 9,
#            'require-103-2': 47,
#            'representation-110.1': 145,
#            'concealment-16-1': 19,
#            'prosecute-33.2-1': 65,
#            'touch-20-1': 81,
#            'disassemble-23.3': 37,
#            'amalgamate-22.2-3': 145,
#            'reject-77.2': 80,
#            'engender-27.1': 203,
#            'put-9.1': 26,
#            'rear-26.2.2': 3,
#            'vehicle_path-51.4.3': 11,
#            'conjecture-29.5': 229,
#            'turn-26.6.1': 74,
#            'banish-10.2': 103,
#            'urge-58.1-1': 176,
#            'inquire-37.1.2': 138,
#            'beg-58.2': 81,
#            'run-51.3.2-1': 103,
#            'relate-86.2-1': 252,
#            'breathe-40.1.2-1': 25,
#            'occur-48.3-2': 55,
#            'sustain-55.6-1': 237,
#            'transfer_mesg-37.1.1-1': 151,
#            'entity_specific_modes_being-47.2': 87,
#            'focus-87.1': 149,
#            'act-114-1-1': 57,
#            'intend-61.2-1-1': 59,
#            'accept-77.1': 121,
#            'masquerade-29.6': 95,
#            'declare-29.4-1-1-3': 14,
#            'support-15.3-1': 68,
#            'stimulus_subject-30.4': 140,
#            'bring-11.3': 164,
#            'substance_emission-43.4-1-1': 3,
#            'masquerade-29.6-2': 482,
#            'clear-10.3': 26,
#            'contribute-13.2': 135,
#            'put-9.1-1': 129,
#            'distinguish-23.5-1': 13,
#            'become-109.1-1': 108,
#            'order-58.3': 49,
#            'attend-107.4-1': 45,
#            'send-11.1-1': 252,
#            'hurt-40.8.3-1-1': 10,
#            'caring-75.2-2': 6,
#            'spray-9.7-1-1': 47,
#            'lecture-37.11-1': 116,
#            'wipe_manner-10.4.1': 26,
#            'contain-15.4': 40,
#            'cheat-10.6.1': 8,
#            'neglect-75.1': 64,
#            'promise-37.13': 38,
#            'long-32.2-1': 196,
#            'resign-10.11-2': 41,
#            'escape-51.1-1-3': 30,
#            'nonvehicle-51.4.2-1': 122,
#            'trick-59.2': 26,
#            'convert-26.6.2-1-1': 42,
#            'meet-36.3-2': 108,
#            'suspect-81': 75,
#            'cut-21.1-1': 56,
#            'interact-36.6': 17,
#            'initiate_communication-37.4.2-1': 21,
#            'fill-9.8-1': 213,
#            'ensure-99': 155,
#            'steal-10.5': 152,
#            'modes_of_being_with_motion-47.3': 100,
#            'nonverbal_expression-40.2': 57,
#            'correspond-36.1.1': 106,
#            'calve-28.1': 1,
#            'exist-47.1-1': 53,
#            'hiccup-40.1.1': 6,
#            'rehearse-26.8-1': 51,
#            'care-88.1-1': 23,
#            'snooze-40.4-1': 18,
#            'curtsey-40.3.3': 8,
#            'render-29.90': 22,
#            'begin-55.1': 53,
#            'help-72.1-2': 12,
#            'slide-11.2': 172,
#            'appeal-31.4-3': 80,
#            'comprehend-87.2-1-1': 43,
#            'bend-45.2': 73,
#            'throw-17.1-1': 81,
#            'braid-41.2.2': 38,
#            'invest-13.5.4-1': 6,
#            'devour-39.4': 34,
#            'coil-9.6': 30,
#            'gorge-39.6': 11,
#            'declare-29.4-1': 31,
#            'wipe_manner-10.4.1-1': 46,
#            'dress-41.1.1': 57,
#            'learn-14-2': 4,
#            'push-12-1': 9,
#            'subjugate-42.3': 64,
#            'absorb-39.8': 36,
#            'leave-51.2-1': 168,
#            'change_bodily_state-40.8.4': 2,
#            'multiply-108-2': 6,
#            'intend-61.2': 16,
#            'tell-37.2': 56,
#            'encounter-30.5': 14,
#            'weekend-56': 7,
#            'acquiesce-95.1-1': 14,
#            'reciprocate-112': 16,
#            'cope-83-1': 19,
#            'intend-61.2-1': 56,
#            'overstate-37.12': 34,
#            'knead-26.5': 26,
#            'rob-10.6.4': 9,
#            'leave-51.2': 44,
#            'addict-96': 41,
#            'comprise-107.2-1': 37,
#            'want-32.1': 31,
#            'subscribe-115': 7,
#            'cooperate-73.1-2': 45,
#            'care-88.1': 4,
#            'gobble-39.3-2': 8,
#            'separate-23.1-2': 26,
#            'declare-29.4-1-1-1': 12,
#            'cooking-45.3': 24,
#            'berry-13.7': 16,
#            'substance_emission-43.4-1': 44,
#            'involve-107.1': 40,
#            'poke-19-1-1': 5,
#            'risk-94': 39,
#            'touch-20': 14,
#            'bump-18.4': 106,
#            'body_internal_motion-49.1': 10,
#            'free-10.6.3': 12,
#            'establish-55.5': 47,
#            'void-106': 8,
#            'floss-41.2.1': 13,
#            'reciprocate-112-1': 22,
#            'funnel-9.3': 14,
#            'hit-18.1-1': 116,
#            'consider-29.9-1-1': 10,
#            'swat-18.2': 38,
#            'chew-39.2-1': 11,
#            'settle-36.1.2': 21,
#            'simple_dressing-41.3.1-2': 3,
#            'bully-59.5': 11,
#            'chew-39.2-2': 4,
#            'nonvehicle-51.4.2': 47,
#            'carry-11.4-1-1': 26,
#            'act-114': 34,
#            'bulge-47.5.3': 2,
#            'swarm-47.5.1-1': 4,
#            'pelt-17.2': 8,
#            'waltz-51.5': 4,
#            'shake-22.3-2': 5,
#            'swarm-47.5.1-2-1': 5,
#            'refrain-69': 5,
#            'drive-11.5-1': 19,
#            'lecture-37.11': 5,
#            'beg-58.2-1-1': 3,
#            'contiguous_location-47.8-1': 6,
#            'crane-40.3.2': 37,
#            'light_emission-43.1': 16,
#            'register-54.1-1': 6,
#            'trifle-105.3': 3,
#            'function-105.2.1': 18,
#            'other_cos-45.4-1': 32,
#            'exhale-40.1.3-1': 3,
#            'smell_emission-43.3': 6,
#            'multiply-108-1': 6,
#            'forbid-64.4': 3,
#            'tingle-40.8.2': 6,
#            'prosecute-33.2': 10,
#            'body_internal_states-40.6': 9,
#            'comprehend-87.2': 6,
#            'respond-113': 2,
#            'admit-64.3': 14,
#            'succeed-74-3-1': 14,
#            'linger-53.1': 14,
#            'captain-29.8': 7,
#            'confine-92': 9,
#            'mix-22.1-1': 2,
#            'ferret-35.6': 3,
#            'say-37.7-1-2': 11,
#            'shake-22.3-1': 3,
#            'spend_time-104': 5,
#            'withdraw-82-3': 5,
#            'rehearse-26.8': 8,
#            'body_motion-49.2-1': 1,
#            'weather-57': 15,
#            'preparing-26.3-2': 7,
#            'cope-83-1-1': 4,
#            'separate-23.1': 8,
#            'rear-26.2.2-1': 4,
#            'support-15.3': 6,
#            'captain-29.8-1-1': 7,
#            'help-72.1-1': 6,
#            'attack-60.1': 7,
#            'birth-28.2-1': 5,
#            'contribute-13.2-2-1': 4,
#            'carve-21.2-3': 15,
#            'substance_emission-43.4': 5,
#            'pain-40.8.1': 4,
#            'wipe_instr-10.4.2-1': 13,
#            'become-109.1': 4,
#            'hurt-40.8.3-1': 2,
#            'work-73.2': 2,
#            'succeed-74-3': 5,
#            'suffocate-40.7': 5,
#            'dine-39.5': 5,
#            'vehicle-51.4.1-1': 3,
#            'cheat-10.6.1-1': 14,
#            'rush-53.2': 3,
#            'dressing_well-41.3.2': 3,
#            'hit-18.1': 10,
#            'debone-10.8': 2,
#            'play-114.2': 1,
#            'orbit-51.9.2': 1,
#            'rotate-51.9.1-1': 1,
#            'groom-41.1.2': 2,
#            'wipe_instr-10.4.2': 3,
#            'gobble-39.3-1': 1,
#            'cling-22.5': 4,
#            'correspond-36.1.1-1-1': 1,
#            'disfunction-105.2.2': 2,
#            'poke-19-1': 2,
#            'mine-10.9': 1,
#            'say-37.7': 2,
#            'shake-22.3-1-1': 1,
#            'amalgamate-22.2-3-2': 1,
#            'amalgamate-22.2-1-1': 2,
#            'birth-28.2': 1,
#            'long-32.2-2': 1,
#            'declare-29.4': 1,
#            'cheat-10.6.1-1-1': 1,
#            'poke-19': 1,
#            'volunteer-95.4-1': 2,
#            'body_motion-49.2-1-1': 1,
#            'pronounce-29.3.1': 1}),
#   'vn_roles': Counter({'Agent': 48654,
#            'Patient': 14213,
#            'Theme': 59135,
#            'Attribute': 12178,
#            'Result': 3137,
#            'Predicate': 527,
#            'Product': 1160,
#            'Causer': 1524,
#            'Topic': 12440,
#            '': 17984,
#            'Destination': 2744,
#            'Recipient': 2965,
#            'Experiencer': 5181,
#            'Stimulus': 5065,
#            'Pivot': 4277,
#            'Co Theme': 785,
#            'Co Agent': 838,
#            'Goal': 1059,
#            'Beneficiary': 525,
#            'Initial State': 378,
#            'Extent': 890,
#            'Initial Location': 371,
#            'Location': 1406,
#            'Value': 653,
#            'Asset': 651,
#            'Co Patient': 860,
#            'Source': 997,
#            'Verb': 153,
#            'Instrument': 178,
#            'Material': 168,
#            'Trajectory': 81,
#            'Circumstance': 31}),
#   'labels': Counter({'A0 <-> Agent <-> agent, entity doing the tying': 160,
#            'A1 <-> Patient <-> first thing being tied': 174,
#            'A1 <-> Theme <-> topic': 11168,
#            'A2 <-> Attribute <-> comment': 10431,
#            'A1 <-> Theme <-> named': 320,
#            'A2 <-> Result <-> name of arg1': 211,
#            'A1 <-> Theme <-> thing used': 667,
#            'A2 <-> Predicate <-> purpose': 345,
#            'A1 <-> Product <-> creation': 390,
#            'A0 <-> Causer <-> forcer, causer': 174,
#            'A1 <-> Theme <-> impelled action': 175,
#            'A1 <-> Topic <-> exposed entity': 13,
#            'A2 <-> exposed to (second entity)': 8,
#            'A0 <-> Agent <-> Reporter': 432,
#            'A0 <-> Theme <-> entity entering': 87,
#            'A1 <-> Destination <-> place or thing entered': 85,
#            'A2 <-> Recipient <-> exposed to (second entity)': 29,
#            'A1 <-> Topic <-> thing seen/shown': 386,
#            'R-A1 <-> Topic <-> thing seen/shown': 4,
#            'A1 <-> Topic <-> Utterance': 7503,
#            'A0 <-> Agent <-> Sayer': 7682,
#            'A0 <-> Agent <-> creator': 898,
#            'R-A0 <-> Agent <-> creator': 101,
#            'A0 <-> Agent <-> Agent/cause': 78,
#            'A1 <-> Theme <-> Theme (action or object being stopped)': 222,
#            'A0 <-> Agent <-> User': 475,
#            'A1 <-> Topic <-> thing reported': 289,
#            'A1 <-> Attribute <-> thing seeming, often requires concatenation': 214,
#            'A0 <-> Agent <-> bringer': 198,
#            'A1 <-> Theme <-> thing brought': 243,
#            'A2 <-> Destination <-> benefactive or destination brought-for, brought-to,': 65,
#            'A0 <-> Agent <-> talker': 230,
#            'A0 <-> Experiencer <-> hearer': 77,
#            'A1 <-> Stimulus <-> utterance, sound': 89,
#            'A0 <-> Pivot <-> owner': 2142,
#            'A1 <-> Theme <-> possession': 2184,
#            'A0 <-> Agent <-> student': 198,
#            'R-A0 <-> Agent <-> student': 16,
#            'A1 <-> Topic <-> subject': 291,
#            'A0 <-> Agent <-> leader': 201,
#            'A1 <-> Theme <-> in the lead of': 145,
#            'A1 <-> Theme <-> old thing': 102,
#            'A2 <-> Co Theme <-> new thing': 65,
#            'A1 <-> Theme <-> Thing Sold': 1139,
#            'A0 <-> Agent': 4922,
#            'R-A0': 557,
#            'A1 <-> Co Agent': 27,
#            'A1 <-> Theme': 6421,
#            'A2': 3897,
#            'C-A1 <-> Theme <-> thing seeming, often requires concatenation': 95,
#            'R-A1 <-> Theme <-> possession': 30,
#            'A0 <-> Experiencer <-> helper': 205,
#            'A1 <-> Stimulus <-> person, thing or project being supported': 210,
#            'A1 <-> Theme <-> thing found': 429,
#            'R-A0 <-> Pivot <-> owner': 235,
#            'A1 <-> Theme <-> thing defined': 45,
#            'R-A1 <-> Theme <-> thing defined': 3,
#            'A2 <-> Attribute <-> secondary attribute, described-as, definition': 19,
#            'A2 <-> Goal': 228,
#            'A1 <-> Theme <-> thing rejected': 89,
#            'A0 <-> Agent <-> rejecter': 79,
#            'A1 <-> Topic <-> thing explained': 106,
#            'A0 <-> Agent <-> explainer': 97,
#            'A0 <-> Agent <-> imposer (not imposter)': 51,
#            'A1 <-> Theme <-> thing imposed': 68,
#            'A2 <-> imposed on': 33,
#            'A1 <-> thing used': 122,
#            'A1 <-> Theme <-> criminal activity': 7,
#            'A0 <-> Agent <-> agent, entity getting rid of something': 33,
#            'A1 <-> Theme <-> thing gotten rid of': 45,
#            'A0 <-> Agent <-> agent, pourer': 19,
#            'A1 <-> Theme <-> liquid': 37,
#            'A0 <-> Agent <-> describer': 105,
#            'A1 <-> Theme <-> thing described': 106,
#            'R-A1': 392,
#            'A0 <-> Agent <-> allower, agent': 1,
#            'A1 <-> Patient <-> stuffy room': 2,
#            'A1 <-> Topic <-> question': 182,
#            'A0 <-> Stimulus': 337,
#            'A1': 2878,
#            'A1 <-> Theme <-> thing continuing': 442,
#            'C-A1 <-> Theme <-> thing continuing': 135,
#            'A1 <-> Theme <-> thing sliding': 36,
#            'A0 <-> Experiencer <-> expecter': 416,
#            'A1 <-> thing expected': 383,
#            'A1 <-> Theme <-> thing followed': 186,
#            'A0 <-> Agent <-> thing following': 103,
#            'A1 <-> Theme <-> thing reported': 160,
#            'A1 <-> Patient <-> Logical subject, patient, thing declining': 345,
#            'A2 <-> EXT, amount declined by': 22,
#            'A4 <-> end point, end state': 8,
#            'A3 <-> start point': 85,
#            'A0 <-> Agent <-> entity acquiring something': 76,
#            'A1 <-> Theme <-> thing being acquired': 90,
#            'A1 <-> Patient': 3341,
#            'A0 <-> Agent <-> investor': 174,
#            'A1 <-> Patient <-> thing getting longer': 7,
#            'A2 <-> EXT': 30,
#            'A4 <-> end point': 132,
#            'A1 <-> Theme <-> Thought': 410,
#            'C-A1 <-> Theme <-> Thought': 28,
#            'A0 <-> Pivot <-> indicator': 111,
#            'A1 <-> Topic <-> thing indicated': 158,
#            'A0 <-> Agent <-> allower': 251,
#            'A2 <-> Beneficiary <-> extracted allowed-agent': 29,
#            'A1 <-> Theme <-> action allowed': 310,
#            'A1 <-> Theme <-> belief': 391,
#            'A0 <-> Agent <-> getter': 16,
#            'A1 <-> Theme <-> thing gotten': 924,
#            'A0 <-> Agent <-> thinker': 221,
#            'C-A1 <-> Theme <-> belief': 15,
#            'A0 <-> Agent <-> thing striving': 140,
#            'A1 <-> Theme <-> goal, destination, end state, thing attained': 207,
#            'C-A1 <-> Topic <-> Utterance': 319,
#            'A1 <-> Theme <-> Logical subject, patient, thing rising': 411,
#            'A1 <-> Patient <-> Logical subject, patient, thing rising': 632,
#            'A4 <-> Result <-> end point': 402,
#            'A3 <-> Initial State <-> start point': 258,
#            'A0 <-> Agent <-> causer of continuation': 169,
#            'A3 <-> Destination <-> destination': 33,
#            'A1 <-> Patient <-> thing grown': 327,
#            'A2 <-> Extent <-> amount increased by, EXT or MNR': 232,
#            'A4 <-> Result <-> end point, end state of arg1': 103,
#            'A0': 1361,
#            'A1 <-> Theme <-> entity in motion/goer': 272,
#            'A2 <-> extent': 55,
#            'A0 <-> Agent <-> Thing giving way': 152,
#            "A1 <-> Theme <-> what's lost": 121,
#            'C-A1 <-> Theme <-> possession': 28,
#            'A2 <-> Recipient <-> invested in': 169,
#            'A0 <-> Agent <-> causer of upward motion, Agent': 82,
#            'R-A0 <-> Agent <-> causer of upward motion, Agent': 10,
#            'A1 <-> Theme <-> Logical subject, thing moving upward': 107,
#            'A4 <-> Result': 206,
#            'A3 <-> Initial State': 102,
#            'A1 <-> Theme <-> Logical subject, patient, thing falling': 233,
#            'A4 <-> Destination <-> end point, end state of arg1': 57,
#            'A3 <-> Initial Location <-> start point': 28,
#            'A0 <-> Agent <-> holder': 290,
#            'R-A0 <-> Agent <-> holder': 25,
#            'A1 <-> Theme <-> thing held': 390,
#            'A2 <-> Stimulus <-> interested in, interesting thing (non-agentive adj subjects, see ex)': 270,
#            'A1 <-> Theme <-> candidate': 94,
#            'A2 <-> Result <-> office or position': 85,
#            'A0 <-> Agent <-> entity succeeding': 216,
#            'A1 <-> Theme <-> task, goal met': 156,
#            'A0 <-> Agent <-> finisher': 70,
#            'A1 <-> Theme <-> task, action coming to an end': 162,
#            'A2 <-> Recipient <-> Buyer': 192,
#            'A1 <-> Theme <-> decision, whole': 267,
#            'A0 <-> Agent <-> employer': 114,
#            'A1 <-> Theme <-> employee': 43,
#            'A0 <-> Agent <-> attacher, agent': 126,
#            'A1 <-> Patient <-> focus of attachment': 126,
#            'A0 <-> Agent <-> elevator, Agent': 15,
#            'A0 <-> Agent <-> player': 226,
#            'A0 <-> Agent <-> issuer': 113,
#            'A1 <-> Theme <-> thing issued': 153,
#            'A1 <-> Patient <-> Logical subject, patient, thing falling': 550,
#            'A0 <-> Agent <-> voter': 87,
#            'A1 <-> Theme <-> candidate or ballot issue': 85,
#            'A0 <-> Agent <-> Agent': 441,
#            'A4 <-> Destination <-> End point': 50,
#            'C-A1': 403,
#            'A0 <-> Agent <-> Seller': 739,
#            'A0 <-> Agent <-> topic/causer/agent of division': 74,
#            'A1 <-> Patient <-> separated entity': 213,
#            'A0 <-> Agent <-> agent, entity causing some grouping, making an   association': 65,
#            'A1 <-> Patient <-> theme, thing being included in some group': 248,
#            'A0 <-> entity causing something/someone to settle': 37,
#            'A4 <-> Location <-> end point': 44,
#            'A0 <-> Agent <-> meeter': 271,
#            'A0 <-> Agent <-> decider': 394,
#            'A1 <-> Goal <-> the decision itself': 88,
#            'A0 <-> Agent <-> assumer of attribute': 22,
#            'A1 <-> Theme <-> entity treated': 32,
#            'A2 <-> Attribute <-> attribute': 134,
#            'A2 <-> benefactive, proved-to': 2,
#            'A1 <-> Theme <-> proposition': 180,
#            'A1 <-> Theme <-> Thing ending': 401,
#            'A0 <-> Theme <-> runner': 52,
#            'A0 <-> Theme': 131,
#            'A0 <-> Agent <-> welcomer': 18,
#            'A1 <-> Theme <-> thing welcomed': 21,
#            'A1 <-> Theme <-> activity/place/item not allowed; banned from': 49,
#            'A2 <-> Beneficiary <-> secondary agent; entity banned from engaging in/entering arg1': 1,
#            'A0 <-> Agent <-> carrier': 82,
#            'A1 <-> Theme <-> thing carried': 94,
#            'A0 <-> Agent <-> drooler': 1,
#            'A1 <-> Theme <-> drool (cognate object)': 2,
#            'A0 <-> Agent <-> pointer': 70,
#            'A1 <-> Patient <-> thing pointed (defaults to finger)': 51,
#            'A0 <-> Agent <-> squeezer': 18,
#            'A2 <-> source': 27,
#            'A1 <-> Theme <-> extracted material': 23,
#            'A0 <-> Theme <-> passenger': 2,
#            'A1 <-> Location <-> vehicle': 2,
#            'A2 <-> Beneficiary <-> secondary predication, arg1 stopped from what, where relevant': 9,
#            'A0 <-> Agent <-> causal agent': 175,
#            'A2 <-> Recipient <-> eater': 22,
#            'A1 <-> Theme <-> food': 15,
#            'A1 <-> Stimulus <-> fact that is known': 428,
#            'A0 <-> Experiencer <-> knower': 331,
#            'A0 <-> Agent <-> consumer, eater': 27,
#            'A1 <-> Patient <-> meal': 20,
#            'A0 <-> Agent <-> giver': 830,
#            'A2 <-> Recipient <-> entity given to': 633,
#            'A1 <-> Theme <-> thing given': 824,
#            'A0 <-> Stimulus <-> agent, tempter': 13,
#            'A1 <-> Experiencer <-> patient, tempted': 6,
#            'A4 <-> Destination': 76,
#            'A0 <-> Agent <-> looker': 240,
#            'A1 <-> Location <-> thing looked at or for or on': 94,
#            'A1 <-> Co Agent <-> person / entity / object being met': 200,
#            'A0 <-> Agent <-> measurer': 41,
#            'A1 <-> Theme <-> thing measured': 97,
#            'A0 <-> Pivot <-> shower': 312,
#            'A0 <-> Agent <-> thrower': 85,
#            'A1 <-> Theme <-> thing thrown': 99,
#            'A2 <-> Destination <-> destination': 159,
#            'A1 <-> Theme <-> thing standing': 58,
#            'A2 <-> Location <-> location': 146,
#            'A4': 162,
#            'A1 <-> Patient <-> thing increasing': 505,
#            'A1 <-> Theme <-> Thing begun - NP, not S-node!': 454,
#            'R-A1 <-> Theme <-> Thing begun - NP, not S-node!': 32,
#            'A3': 723,
#            'A0 <-> Agent <-> recorder': 20,
#            'A1 <-> Theme <-> record': 32,
#            'A0 <-> Agent <-> Agent/Entity Trying': 324,
#            'A1 <-> Theme <-> thing tried': 346,
#            'A0 <-> Agent <-> announcer': 357,
#            'A1 <-> Topic <-> utterance': 715,
#            'A0 <-> Agent <-> entity making introduction': 79,
#            'A1 <-> Patient <-> entity being introduced': 134,
#            'A1 <-> thing planned': 380,
#            'A0 <-> Experiencer <-> planner': 510,
#            'A1 <-> Theme <-> commodity': 1566,
#            'A0 <-> Agent <-> entity offering': 423,
#            'A3 <-> Goal <-> benefactive or entity offered to': 88,
#            'R-A0 <-> Agent <-> giver': 53,
#            'A0 <-> Agent <-> maintainer': 61,
#            'A1 <-> Theme <-> thing maintained': 87,
#            'A0 <-> Causer <-> causer of increase': 176,
#            'A0 <-> Agent <-> competitor': 104,
#            'A1 <-> Destination <-> container': 286,
#            'A2 <-> Value <-> price': 221,
#            'A0 <-> Agent <-> entity moving something downward': 55,
#            'A1 <-> Theme <-> Logical subject, patient, thing going down': 67,
#            'A1 <-> Theme <-> award': 48,
#            'A2 <-> Goal <-> beneficiary': 41,
#            'A3 <-> reason': 4,
#            'A2 <-> Theme <-> credited for': 34,
#            'R-A0 <-> Agent <-> meeter': 15,
#            "A0 <-> Theme <-> thing that's more": 71,
#            "R-A0 <-> Theme <-> thing that's more": 9,
#            "A1 <-> Co Theme <-> thing that's less": 73,
#            'A0 <-> Agent <-> spender, buyer': 113,
#            'A3 <-> Asset <-> price paid, money': 76,
#            'A1 <-> Theme <-> thing being counted': 100,
#            'A2 <-> Value <-> count': 100,
#            'A1 <-> Experiencer <-> thing that matters': 16,
#            'A1 <-> money or attention': 38,
#            'A0 <-> Agent <-> payer or buyer': 490,
#            'A3 <-> Theme <-> commodity, paid for what': 195,
#            'A0 <-> Agent <-> agent, entity acquiring something': 393,
#            'A1 <-> Theme <-> thing acquired': 488,
#            'A2 <-> Goal <-> purpose': 65,
#            'C-A1 <-> thing used': 1,
#            'A1 <-> task, goal met': 25,
#            'A0 <-> Agent <-> retiree': 64,
#            'A2 <-> Extent <-> EXT, amount risen': 374,
#            'A0 <-> Agent <-> agent, setter': 302,
#            'A1 <-> Theme <-> thing set': 291,
#            'A1 <-> Patient <-> first item in comparison': 179,
#            'A2 <-> Co Patient <-> second item in comparison, usually prepositional': 232,
#            'A1 <-> Theme <-> entity in motion': 112,
#            'A5 <-> direction': 13,
#            'A0 <-> Causer': 756,
#            'A1 <-> Patient <-> thing increasing, rising': 51,
#            'A0 <-> Agent <-> opener': 84,
#            'A1 <-> Patient <-> thing opening': 223,
#            'A1 <-> Result <-> creation': 377,
#            'A0 <-> Agent <-> helper': 392,
#            'A1 <-> Theme <-> project': 369,
#            'A1 <-> Patient <-> thing becoming diverse': 9,
#            'A1 <-> Theme <-> favor': 124,
#            'A0 <-> Agent <-> claimer, asserter': 157,
#            'A1 <-> Topic <-> thing claimed, asserted': 164,
#            'A0 <-> Agent <-> entity removing': 188,
#            'A1 <-> Theme <-> thing being removed': 227,
#            'A2 <-> Initial Location <-> removed from': 51,
#            'A2 <-> Theme <-> task': 116,
#            'A0 <-> Agent <-> holder of patent': 20,
#            'A3 <-> Location': 54,
#            'A0 <-> Agent <-> looker, facer': 168,
#            'A1 <-> Theme <-> looked at, faced': 169,
#            'A0 <-> Agent <-> improver': 69,
#            'A1 <-> Patient <-> thing improving': 165,
#            'A0 <-> Agent <-> protector': 79,
#            'A1 <-> protected': 3,
#            'A1 <-> Theme <-> thing put': 438,
#            'R-A1 <-> Theme <-> thing put': 9,
#            'A0 <-> Agent <-> putter': 340,
#            'A2 <-> Destination <-> where put': 309,
#            'A1 <-> Patient <-> thing moving': 29,
#            'A2 <-> aspect of arg1 that is actually progressing': 4,
#            'C-A1 <-> Theme <-> topic': 74,
#            'A0 <-> Stimulus <-> agent, Stimulus': 21,
#            'A1 <-> Experiencer <-> entity damaged': 12,
#            'A1 <-> Beneficiary': 6,
#            'A0 <-> Experiencer <-> agent, entity causing damage': 4,
#            'A1 <-> Patient <-> patient, entity experiencing hurt/damage': 4,
#            'A0 <-> Agent <-> entity removing confidence, agent': 19,
#            'A1 <-> Theme <-> entity discouraged': 23,
#            'A0 <-> Agent <-> agent, deterer': 11,
#            'A1 <-> Beneficiary <-> patient, entity deterred': 4,
#            'A2 <-> Theme <-> secondary action (deter from X)': 4,
#            'A1 <-> Theme <-> thing invested': 71,
#            'A0 <-> Agent <-> praiser, agent': 2,
#            'A1 <-> Theme <-> entity praised': 2,
#            'A2 <-> Attribute <-> praised for what?': 2,
#            'A1 <-> Result <-> thing created': 246,
#            'A2 <-> Theme <-> trainee': 24,
#            'A1 <-> Attribute <-> skill': 9,
#            'A1 <-> Patient <-> thing set': 68,
#            'A2 <-> Beneficiary <-> benefactor': 9,
#            'A0 <-> Agent <-> signer, initialler': 2,
#            'A1 <-> Theme <-> document': 25,
#            'A3 <-> instrument': 55,
#            'A1 <-> Theme <-> protected': 104,
#            'A2 <-> danger': 31,
#            'A0 <-> Agent <-> causer': 67,
#            'A1 <-> Patient <-> impelled agent': 377,
#            'A2 <-> Predicate <-> impelled action': 9,
#            'A2 <-> Recipient <-> person being paid, destination of attention': 177,
#            'A0 <-> Agent <-> shower': 68,
#            'A1 <-> Theme <-> thing seen/shown': 30,
#            'A0 <-> Agent <-> applier': 15,
#            'A1 <-> Theme <-> thing applied, associated, worked': 58,
#            'A2 <-> Predicate <-> applied to': 47,
#            'R-A2': 97,
#            'A1 <-> Experiencer <-> worried entity': 173,
#            'A1 <-> Theme <-> object, thing under consideration': 28,
#            'A0 <-> Agent <-> poser': 20,
#            'A1 <-> Topic <-> question, etc': 19,
#            'A0 <-> Stimulus <-> agent, entity making a threat': 93,
#            'A0 <-> Agent <-> violent entity, agent': 3,
#            'A1 <-> Patient <-> ingredient one': 129,
#            'A2 <-> Co Patient <-> ingredient two': 52,
#            'A1 <-> Experiencer <-> interested entity': 202,
#            'A0 <-> Agent <-> causer, prompter': 47,
#            'A0 <-> Agent <-> Speaker': 260,
#            'A2 <-> Recipient <-> Hearer': 328,
#            'A1 <-> Result <-> theme': 6,
#            'A0 <-> Stimulus <-> causer of concern': 311,
#            'A1 <-> Experiencer <-> disturbed': 15,
#            'A0 <-> Agent <-> speaker': 520,
#            'A0 <-> Agent <-> complainer': 131,
#            'A1 <-> Topic <-> cause, complain of or about': 91,
#            'A1 <-> Theme <-> invention': 16,
#            'A0 <-> requirer': 259,
#            "A2 <-> required-of, required-from ('ablative')": 94,
#            'A1 <-> Theme <-> thing required': 353,
#            'A0 <-> Agent <-> assigner': 109,
#            'A1 <-> Theme <-> thing provided': 472,
#            'A0 <-> Agent <-> provider': 372,
#            'A0 <-> Agent <-> asker': 365,
#            'A2 <-> hearer': 99,
#            'A1 <-> Patient <-> favor': 138,
#            'A1 <-> Theme <-> believed': 285,
#            'C-A1 <-> Theme <-> believed': 18,
#            'A1 <-> Theme <-> entity summoned': 182,
#            'C-A1 <-> Theme <-> entity summoned': 9,
#            'A0 <-> Agent <-> caller': 359,
#            'A1 <-> Theme <-> money or attention': 252,
#            'A2 <-> EXT, amount fallen': 137,
#            'A0 <-> Experiencer <-> feeler, person experiencing emotion': 95,
#            'A1 <-> Stimulus <-> emotion or sensation': 104,
#            'A1 <-> Theme <-> the problem': 51,
#            'A0 <-> Pivot <-> Wanter': 512,
#            'A1 <-> Theme <-> thing wanted': 510,
#            'A2 <-> Attribute <-> for what': 7,
#            'A1 <-> Agent <-> thing standing': 50,
#            'R-A1 <-> Agent <-> thing standing': 13,
#            'A0 <-> Agent <-> causer of transformation': 190,
#            'A1 <-> Patient <-> thing changing': 664,
#            'A1 <-> Product <-> construction': 342,
#            'R-A1 <-> Product <-> construction': 8,
#            'A0 <-> Agent <-> builder': 285,
#            'A1 <-> Product <-> thing created': 266,
#            'A1 <-> Result <-> entity modeled': 44,
#            'A0 <-> Agent <-> storer': 6,
#            'A0 <-> Agent <-> agent, adaptor': 14,
#            'A1 <-> Patient <-> thing adapted': 13,
#            'A1 <-> Theme <-> vehicle or path': 38,
#            'R-A0 <-> Agent <-> allower': 48,
#            'A3 <-> Asset <-> price paid': 74,
#            'R-A0 <-> Agent <-> Seller': 44,
#            'A2 <-> EXT, amount risen': 84,
#            'A1 <-> Result <-> thing scheduled': 85,
#            'A2 <-> scheduled to, for or because of; 2nd part of event': 43,
#            'A3 <-> Destination <-> attribute, state after bringing, secondary action': 42,
#            'A1 <-> Theme <-> Theme(-Creation)': 348,
#            'C-A1 <-> Theme <-> Theme(-Creation)': 58,
#            'A3 <-> Asset <-> Price Paid': 74,
#            'A2 <-> thing followed, coming before': 43,
#            'A1 <-> Theme <-> thing following, coming after': 97,
#            'A2 <-> Source <-> removed from': 30,
#            'A0 <-> Agent <-> buyer': 569,
#            'A1 <-> Theme <-> thing bought': 601,
#            'A4 <-> Goal': 33,
#            'A0 <-> Agent <-> speaker, snapper': 11,
#            'A1 <-> Theme <-> theme, thing being included in some group': 24,
#            'A0 <-> Agent <-> agent, entity causing some grouping': 14,
#            'A1 <-> Patient <-> first or all things being tied': 47,
#            'A2 <-> Co Patient <-> second thing, linked to what': 34,
#            'A1 <-> Result <-> thing designed': 120,
#            'A3 <-> purpose': 57,
#            'A2 <-> Theme <-> thing in jeopardy, asset that could be lost, or negative outcome risked': 92,
#            'A1 <-> Source <-> former job': 16,
#            'A0 <-> Agent <-> director': 5,
#            'A1 <-> Theme <-> thing directed': 6,
#            'A2 <-> Destination <-> direction, towards what': 6,
#            'A0 <-> Causer <-> Agent': 172,
#            'A0 <-> Agent <-> loader': 22,
#            'A1 <-> Recipient <-> carrier': 15,
#            'A1 <-> Destination <-> item being addressed (letter, speech, etc)': 37,
#            'A0 <-> Agent <-> purchaser': 159,
#            'C-A1 <-> Theme <-> thing bought': 4,
#            'A0 <-> Agent <-> agreer': 316,
#            'A1 <-> Topic <-> proposition': 267,
#            'A0 <-> Agent <-> filer': 180,
#            'A1 <-> Theme <-> file': 193,
#            'A2 <-> Extent': 31,
#            'A0 <-> Agent <-> signifier': 35,
#            'A1 <-> Theme <-> signified': 43,
#            'A2 <-> Co Theme <-> thing followed, coming before': 26,
#            'A1 <-> Theme <-> thing picked': 165,
#            'R-A0 <-> Agent <-> investor': 12,
#            'A1 <-> Theme <-> thing registered': 26,
#            'A2 <-> registered with or for': 9,
#            'A1 <-> Theme <-> thing moving': 173,
#            'A3 <-> Location <-> start or low point': 54,
#            'A4 <-> end or high point': 57,
#            'A1 <-> Destination <-> thing topped': 28,
#            'A2 <-> top': 3,
#            'A0 <-> Agent <-> visitor': 72,
#            'A0 <-> Agent <-> kicker': 9,
#            'A1 <-> Theme <-> thing kicked': 4,
#            'A1 <-> Patient <-> bomb, thing exploding': 7,
#            'A1 <-> Theme <-> thing being traded (away)': 170,
#            'R-A1 <-> Theme <-> thing being traded (away)': 12,
#            'A1 <-> Topic <-> item': 52,
#            'R-A1 <-> Topic <-> item': 4,
#            'A2 <-> list': 34,
#            'A1 <-> Theme <-> thing looked at or for or on': 171,
#            'A1 <-> Theme <-> logical subject, thing ranging': 78,
#            'A1 <-> Destination': 28,
#            'A0 <-> Agent <-> finder': 412,
#            'A0 <-> agent, entity making something be longer': 6,
#            'A1 <-> Theme <-> patient, thing getting longer': 21,
#            'A2 <-> EXT or TMP, by how much or until when': 6,
#            'A0 <-> Agent <-> urger': 80,
#            'A2 <-> Result <-> impelled action': 223,
#            'A1 <-> Stimulus <-> food': 8,
#            'A1 <-> Theme <-> thing sought, attempted action': 284,
#            'A0 <-> Agent <-> seller, pricer': 82,
#            'A1 <-> Theme <-> thing swinging': 7,
#            'A2 <-> Extent <-> EXT, amount fallen': 121,
#            'A1 <-> Patient <-> thing hit': 105,
#            'A0 <-> Agent <-> agent, entity trading': 60,
#            'A3 <-> other item in exchange, price, or premium, traded for or at': 23,
#            'A2 <-> price': 116,
#            'A1 <-> Patient <-> climber': 47,
#            'A2 <-> Extent <-> ext, amount risen': 26,
#            'A1 <-> Patient <-> thing closing': 313,
#            'R-A1 <-> Patient <-> thing closing': 9,
#            'A2 <-> anti-beneficiary': 14,
#            'A1 <-> Theme <-> thing aimed at': 32,
#            'A0 <-> Agent <-> targeter': 28,
#            'A2 <-> Co Patient <-> second thing, tied to what': 58,
#            'A1 <-> Patient <-> first (or all) thing(s) being integrated': 22,
#            'A3 <-> attribute of arg1 that is actually undergoing integration': 2,
#            'R-A1 <-> Theme <-> thing invested': 1,
#            'A0 <-> Experiencer <-> viewer': 431,
#            'A1 <-> Stimulus <-> thing viewed': 490,
#            'A1 <-> Topic <-> Utterance (suggestion)': 173,
#            'A0 <-> Agent <-> Agent / entity seeking': 266,
#            'A1 <-> Theme <-> exposed entity': 30,
#            'A0 <-> Agent <-> insister': 100,
#            'R-A0 <-> Agent <-> insister': 6,
#            'A1 <-> Topic <-> thing insisted, required': 102,
#            'R-A0 <-> Agent <-> buyer': 52,
#            'A1 <-> Asset <-> money or attention': 169,
#            'A1 <-> Theme <-> price paid': 28,
#            'A2 <-> Goal <-> seller or person being paid': 25,
#            'A1 <-> Theme <-> thing bought or paid for': 15,
#            'A0 <-> Agent <-> cleaner': 41,
#            'A1 <-> Theme <-> thing made clean': 23,
#            'A1 <-> Theme <-> event': 158,
#            'A1 <-> Theme <-> thing approved': 155,
#            'A1 <-> Theme <-> victim': 7,
#            'A1 <-> Theme <-> entity settling': 98,
#            'A1 <-> Theme <-> thing lent': 30,
#            'R-A1 <-> Theme <-> thing lent': 1,
#            'A2 <-> Recipient <-> lent-to': 31,
#            'A0 <-> Agent <-> giver, offerer': 8,
#            'A1 <-> Theme <-> thing offered': 8,
#            'A2 <-> Recipient <-> offered-to': 6,
#            'A1 <-> Goal': 42,
#            'A3 <-> Location <-> start point': 13,
#            'A0 <-> Agent <-> stresser, agent': 27,
#            'A1 <-> Destination <-> thing stressed': 30,
#            'A2 <-> attribute': 34,
#            'A1 <-> Experiencer <-> patient, entity pleased/fulfilled': 42,
#            'A1 <-> Patient <-> thing becoming level': 6,
#            'A1 <-> Theme <-> thing ordered': 107,
#            'A1 <-> Agent <-> thing failing': 200,
#            'A0 <-> Agent <-> examiner': 160,
#            'A4 <-> Destination <-> end point': 77,
#            'A3 <-> Topic <-> text, content': 21,
#            'A0 <-> Agent <-> orderer': 58,
#            'A4 <-> Goal <-> purpose, reason for adjustment': 4,
#            'A4 <-> purpose, reason for adjustment': 18,
#            'C-A1 <-> Theme <-> Thing begun - NP, not S-node!': 116,
#            'A0 <-> Agent <-> The Reanimator': 18,
#            'A1 <-> Patient <-> thing or system being brought back': 34,
#            'A0 <-> Agent <-> picker': 130,
#            'A0 <-> Pivot <-> fortune teller': 116,
#            'A1 <-> Topic <-> prediction': 119,
#            'A1 <-> Patient <-> moved': 94,
#            'A2 <-> destination': 41,
#            'R-A0 <-> Agent <-> provider': 44,
#            'A0 <-> Stimulus <-> causer': 26,
#            'A1 <-> Experiencer <-> thing provoked, or reaction when separate secondary impelled agent is present': 9,
#            'A1 <-> Patient <-> entity conforming': 11,
#            'A2 <-> Goal <-> entity conforming to': 8,
#            'A1 <-> Theme <-> thing that lasts': 36,
#            'A2 <-> Value <-> period of time': 28,
#            'A0 <-> Agent <-> estimator': 116,
#            'A1 <-> Theme <-> thing estimated': 149,
#            'A1 <-> Stimulus <-> utterance': 229,
#            'A0 <-> Experiencer <-> noter': 229,
#            'A2 <-> Extent <-> EXT, amount declined by': 50,
#            'A1 <-> Result <-> construction': 62,
#            'A2 <-> EXT, distance run': 9,
#            'A0 <-> Agent <-> counter': 13,
#            'A1 <-> Theme <-> thing counted': 31,
#            'A3 <-> price paid, money': 52,
#            'A1 <-> thing bought, commodity': 55,
#            'A1 <-> Patient <-> entity in motion': 84,
#            'A0 <-> Agent <-> adder': 125,
#            'A1 <-> Patient <-> thing being added': 170,
#            'A1 <-> Theme <-> thing purchased': 201,
#            'A0 <-> Agent <-> sender': 234,
#            'A1 <-> Theme <-> sent': 302,
#            'A1 <-> Patient <-> entity decreased': 9,
#            'A0 <-> Agent <-> handler': 95,
#            'A2 <-> Source <-> justification, parts/ arg1 is made up of what?': 152,
#            'A1 <-> Topic <-> proposition, claim, utterance': 51,
#            'A0 <-> Agent <-> admitter, claimer, speaker': 52,
#            'A0 <-> Agent <-> factors': 6,
#            'A1 <-> Patient <-> led entity': 8,
#            'A2 <-> Predicate <-> result, action or attribute on arg1': 8,
#            'A0 <-> Agent <-> suspecter': 29,
#            'A1 <-> Theme <-> suspicion: what arg0 thinks': 27,
#            'A1 <-> Agent <-> thing being counted': 7,
#            'A2 <-> Theme <-> count, number, quantity': 5,
#            'A0 <-> Agent <-> blamer': 35,
#            'A1 <-> Theme <-> entity blamed': 57,
#            'A1 <-> Patient <-> first thing': 5,
#            'A2 <-> Patient <-> second thing': 4,
#            'A2 <-> Destination <-> location or position': 84,
#            'A0 <-> Agent <-> drinker': 20,
#            'A1 <-> Patient <-> liquid': 14,
#            'A0 <-> Agent <-> reader': 70,
# ...
#            'A0 <-> Agent <-> student': 3,
#            'A0 <-> Agent <-> entity causing separation': 4,
#            'A1 <-> Asset <-> thing wasted': 1,
#            'A1 <-> Patient <-> thing undergoing decomposition': 5,
#            'A1 <-> Theme <-> commodity being exchanged': 2,
#            'R-A1 <-> Result <-> thing created': 3,
#            'A0 <-> Agent <-> cause, agent': 1,
#            'A1 <-> thing emit': 1,
#            'A0 <-> Theme <-> emitter': 1,
#            'A1 <-> Topic <-> utterance': 2,
#            'A0 <-> Agent <-> causer of transformation': 3,
#            'A1 <-> Stimulus <-> thing sensed': 2,
#            'A1 <-> Theme <-> Theme(-Creation)': 3,
#            'A0 <-> Causer': 1,
#            'A0 <-> Agent <-> player': 1,
#            'R-A0 <-> Agent <-> player': 1,
#            'A1 <-> Attribute <-> role': 2,
#            'R-A1 <-> Patient <-> thing being added': 1,
#            'A1 <-> Location <-> thing looked at': 4,
#            'A1 <-> Theme <-> entity liberated': 1,
#            'A1 <-> Theme <-> thing existing': 2,
#            'C-A1 <-> Theme <-> thing existing': 1,
#            'A3 <-> Destination <-> destination': 2,
#            'A1 <-> Theme <-> thing being pitched, advertised': 1,
#            'A0 <-> Agent <-> transporter': 1,
#            'A2 <-> Asset <-> seller': 1,
#            'A3 <-> Beneficiary <-> benefactive': 2,
#            'A2 <-> Beneficiary <-> created-from, thing changed': 1,
#            'A1 <-> Theme <-> thing avoided': 2,
#            'A1 <-> Patient <-> corporation': 2,
#            'A1 <-> Theme <-> removed': 5,
#            'A1 <-> Destination <-> covered': 6,
#            'A1 <-> Patient <-> entity getting old': 4,
#            'A2 <-> Material <-> created-from, thing changed': 2,
#            'A0 <-> Agent <-> causal agent': 3,
#            'C-A1 <-> Theme <-> thing being removed': 1,
#            'R-A1 <-> Stimulus <-> detected': 1,
#            'A2 <-> Recipient <-> end state': 2,
#            'A1 <-> Destination <-> beast of burden': 10,
#            'A0 <-> Agent <-> recommender, sender': 1,
#            'A1 <-> Theme <-> recommended thing': 1,
#            'C-A1 <-> Result <-> creation': 1,
#            'R-A1 <-> Theme <-> thing acquired': 1,
#            'R-A1 <-> Patient <-> thing being washed': 1,
#            'A1 <-> Recipient <-> battery, usually': 1,
#            'A0 <-> Agent <-> assistant': 2,
#            'A2 <-> Theme <-> project': 1,
#            'A1 <-> Theme <-> thing dipped': 3,
#            'A2 <-> Destination <-> dipped into': 2,
#            'A0 <-> Agent <-> finisher': 1,
#            'A1 <-> Theme <-> moved': 5,
#            'A1 <-> Theme <-> thing following, coming after': 3,
#            'A2 <-> thing followed, coming before': 2,
#            'R-A1 <-> Theme <-> thing set': 1,
#            'A2 <-> Destination <-> location or position': 5,
#            'A1 <-> Destination <-> thing covered': 4,
#            'A2 <-> Theme <-> covered with': 4,
#            'A1 <-> Theme <-> thing specified': 4,
#            'A0 <-> Experiencer <-> helper': 2,
#            'A0 <-> Experiencer <-> observer': 1,
#            'A0 <-> Agent <-> adder': 3,
#            'C-A1 <-> Theme <-> thing given': 2,
#            'R-A1 <-> Theme <-> entity treated': 1,
#            'A1 <-> Beneficiary <-> assisted': 1,
#            'A1 <-> Patient <-> thing freezing': 2,
#            'C-V <-> Verb': 1,
#            'V <-> Verb': 1,
#            'A1 <-> Theme <-> thing that lasts': 1,
#            'A2 <-> Value <-> period of time': 1,
#            'A0 <-> Agent <-> influencer': 1,
#            'A1 <-> Patient <-> influenced': 1,
#            'A2 <-> attribute (how old)': 3,
#            'A1 <-> Theme <-> depended on': 2,
#            'A0 <-> Agent <-> depender': 1,
#            'A2 <-> Result <-> attribute, label itself': 5,
#            'A0 <-> Experiencer <-> detector': 2,
#            'A1 <-> Patient <-> thing becoming warm': 1,
#            'A0 <-> Agent': 13,
#            'A1 <-> Patient <-> water': 3,
#            'A1 <-> Theme <-> substance leaked': 4,
#            'R-A1 <-> Theme <-> sent': 1,
#            'A1 <-> Theme <-> entity attained': 1,
#            'A0 <-> Agent <-> Thing giving way': 2,
#            "A1 <-> Theme <-> what's lost": 2,
#            'A1 <-> Theme <-> mark': 1,
#            'A2 <-> Destination <-> surface, marked-on': 1,
#            'A2 <-> Instrument <-> Instrument': 4,
#            'A0 <-> Agent <-> acceptor, pursuer': 1,
#            'A1 <-> Theme <-> designated': 2,
#            'A2 <-> Result <-> role of arg1': 2,
#            'A1 <-> Theme <-> thing standing': 1,
#            'A3 <-> start state': 3,
#            'A0 <-> Agent <-> entity removing': 6,
#            'A1 <-> Destination <-> surface': 2,
#            'A2 <-> Theme <-> image': 3,
#            'A1 <-> Theme <-> exposed entity': 1,
#            'C-A0 <-> Agent <-> causer of group, agent': 1,
#            'A3 <-> Initial State <-> start point': 2,
#            'A3 <-> secondary attribute of arg1': 2,
#            'A1 <-> Source <-> entity peeled': 3,
#            'A1 <-> Patient <-> thing grown': 1,
#            'A2 <-> Product <-> end state': 2,
#            'A1 <-> Value <-> thing carried': 1,
#            'A1 <-> Theme <-> substance': 1,
#            'A0 <-> Agent <-> observer': 3,
#            'A1 <-> Theme <-> thing achieved, gotten, accomplished': 5,
#            'A1 <-> Stimulus <-> fact that is known': 3,
#            'A0 <-> Agent <-> describer': 6,
#            'A1 <-> Patient <-> first item in comparison': 3,
#            'A2 <-> Co Patient <-> second item in comparison, usually prepositional': 2,
#            'A2 <-> instrument': 1,
#            'A1 <-> Patient <-> thing made ready': 2,
#            'A0 <-> Agent <-> preparer': 2,
#            'A2 <-> ready for': 1,
#            'A2 <-> powder, pieces': 1,
#            'A1 <-> Experiencer <-> thing trembling': 2,
#            'C-A1 <-> Theme <-> employee': 1,
#            'A1 <-> Theme <-> thing being traded (away)': 1,
#            'A3 <-> other item in exchange, price, or premium, traded for or at': 1,
#            'A1 <-> Patient <-> thing cleaned': 7,
#            'A2 <-> Instrument <-> beneficiary, cost:  clean for': 2,
#            'A1 <-> Patient <-> biased entity': 1,
#            'A3 <-> against': 1,
#            'A1 <-> Patient <-> thing cleaned up': 1,
#            'R-A1 <-> Theme <-> thing measured': 2,
#            'A1 <-> Theme <-> theme, thing being included in some group': 3,
#            'A1 <-> Theme <-> thing estimated': 3,
#            'A0 <-> Agent <-> estimator': 2,
#            'A2 <-> justification, parts/ arg1 is made up of what?': 1,
#            'R-A1 <-> Theme <-> thing deposited': 1,
#            'A1 <-> Theme <-> thing emitted': 3,
#            'A1 <-> Patient <-> thing moving': 1,
#            'A2 <-> impurities/contaminants': 1,
#            'A2 <-> Theme <-> in search of, for what': 1,
#            'A1 <-> Theme <-> posted': 1,
#            'A2 <-> entity extracted from': 1,
#            'A1 <-> Theme <-> thing used again': 1,
#            'A0 <-> Agent <-> entity causing isolation': 1,
#            'A0 <-> Agent <-> entity moving something downward': 1,
#            'A1 <-> Theme <-> Logical subject, patient, thing going down': 1,
#            'A2 <-> Beneficiary': 2,
#            'A0 <-> Pivot <-> shower': 2,
#            'A1 <-> Patient <-> thing becoming shorter': 1,
#            'A1 <-> Theme <-> entity resting': 1,
#            'A1 <-> Theme <-> thing stabled': 2,
#            'A1 <-> Theme <-> thing grounded': 2,
#            'A3 <-> Initial State <-> start state': 4,
#            'A1 <-> Patient <-> first thing being tied': 3,
#            'A2 <-> Co Patient <-> second thing, tied to what': 3,
#            'A1 <-> Patient <-> thing': 3,
#            'A2 <-> Attribute <-> secondary attribute, described-as': 5,
#            'A2 <-> beneficiary, cost:  clean for': 2,
#            'A0 <-> Agent <-> adopter': 1,
#            'A1 <-> Theme <-> thing adopted': 1,
#            'A1 <-> Agent <-> thing standing': 1,
#            'R-A1 <-> Agent <-> thing standing': 1,
#            'A1 <-> thing used': 2,
#            'A4 <-> attribute of arg1': 1,
#            'A1 <-> Theme <-> Logical subject, patient, thing falling': 1,
#            'A1 <-> Destination <-> thing getting shiny': 1,
#            'A2 <-> Theme <-> instrument': 1,
#            'A0 <-> Causer <-> Agent': 2,
#            'A1 <-> Theme <-> dirt': 1,
#            'A1 <-> Destination <-> thing getting wet': 4,
#            'A2 <-> Initial Location <-> location': 1,
#            'A0 <-> Agent <-> recorder': 1,
#            'A1 <-> Theme <-> entity embedded': 1,
#            'A2 <-> Destination <-> embedded into': 1,
#            'A1 <-> Destination <-> thing decorated': 1,
#            'A1 <-> Source <-> degreased entity': 1,
#            'A0 <-> Agent <-> remover': 1,
#            'A0 <-> Agent <-> worker, entity performing a service/acting in some capacity': 1,
#            'A1 <-> Attribute <-> job, project, service performed': 1,
#            'A1 <-> Patient <-> thing attached': 1,
#            'A1 <-> Location <-> examined': 7,
#            'A2 <-> Instrument': 3,
#            'A1 <-> Patient <-> thing emitting clicks': 1,
#            'A1 <-> Theme <-> file': 1,
#            'A2 <-> Theme <-> people': 1,
#            'A0 <-> Agent <-> cause': 1,
#            'A1 <-> Patient <-> entity turned into vapor': 1,
#            'A1 <-> Patient <-> theme, thing diffused': 2,
#            'A0 <-> Agent <-> allower': 1,
#            'A1 <-> Theme <-> thing distributed': 1,
#            'A2 <-> Recipient <-> distributed to': 1,
#            'A1 <-> Patient <-> thing getting coarse': 1,
#            'A1 <-> Patient <-> thing limited': 2,
#            'A1 <-> Topic <-> Utterance': 1,
#            'A2 <-> Recipient <-> Hearer': 1,
#            'A1 <-> Theme <-> thing required': 1,
#            'A0 <-> requirer': 1,
#            'A1 <-> Result <-> thing designed': 4,
#            'A2 <-> Material': 2,
#            'A2 <-> examined for': 1,
#            'A0 <-> Agent <-> examiner': 3,
#            'A1 <-> Result <-> construction': 2,
#            'A0 <-> Agent <-> builder': 1,
#            'A1 <-> Product <-> crop': 5,
#            'A2 <-> source': 1,
#            'A3 <-> Initial Location <-> sent-from': 1,
#            'A1 <-> Patient <-> thing falling': 2,
#            'A2 <-> Extent <-> EXT': 2,
#            'A1 <-> Theme <-> entity in motion/goer': 1,
#            'A1 <-> Theme <-> Thing begun - NP, not S-node!': 2,
#            'A0 <-> Agent <-> seller': 1,
#            'A1 <-> Asset <-> asking price': 1,
#            'A3 <-> Asset <-> commodity': 1,
#            'A3 <-> Result': 1,
#            'A3 <-> secondary attribute of thing given': 1,
#            'A1 <-> Topic <-> testimony, evidence for': 1,
#            'A0 <-> Agent <-> witness, agent': 1,
#            'A1 <-> Theme <-> entity displayed': 1,
#            'A2 <-> location': 1,
#            'A1 <-> Product <-> thing created': 2,
#            'R-A1 <-> Product <-> thing created': 1,
#            'R-A1 <-> Theme <-> decision, whole': 1,
#            'A2 <-> EXT, amount risen': 1,
#            'A1 <-> Theme <-> thing continuing': 3,
#            'A2 <-> estimated-to-be, attribute of arg1': 1,
#            'A1 <-> Theme <-> thing procured': 2,
#            'A4 <-> Result <-> end point, end state of arg1': 3,
#            'A1 <-> Patient <-> thing fading': 1,
#            'A2 <-> with what, how, if in addition to arg0': 2,
#            'A1 <-> Patient <-> entity being introduced': 2,
#            'A3 <-> Initial Location': 1,
#            'A1 <-> Source <-> starting point, location vacated': 1,
#            'C-A1 <-> Source <-> starting point, location vacated': 1,
#            'A0 <-> Agent <-> causer of degradation': 1,
#            'A2 <-> Asset <-> received from': 1,
#            'A4 <-> end point, end state of arg1': 1,
#            'A1 <-> Theme <-> soluble constituents, product of leaching process': 1,
#            'A2 <-> Source <-> source from which arg1 is drawn, pure substance undergoing percolation': 1,
#            'A1 <-> Patient <-> thing highlighted': 1,
#            'A0 <-> Agent <-> exhibiter': 2,
#            'A1 <-> Theme <-> thing seen/exhibition': 2,
#            'A1 <-> thing bought or paid for, compensated for what?': 1,
#            'A2 <-> Theme <-> seller or person being paid': 1,
#            'A2 <-> Result': 1,
#            'A1 <-> Theme <-> thing changing hands': 1,
#            'A0 <-> Pivot <-> implier': 1,
#            'A1 <-> Topic <-> implication': 1,
#            'A0 <-> Agent <-> user, agent': 1,
#            'A1 <-> Theme <-> entity utilized': 2,
#            'A2 <-> Trajectory': 1,
#            'R-A1 <-> Theme <-> thing put': 1,
#            'A1 <-> Patient <-> entity sliced': 1,
#            'A3 <-> price paid': 1,
#            'A1 <-> Patient <-> separated entity': 1,
#            'A2 <-> divided among/ between': 1,
#            'A1 <-> Theme <-> agreement': 1,
#            'A2 <-> Attribute <-> co-signer': 1,
#            'A1 <-> Theme <-> event': 3,
#            'A1 <-> Theme <-> new knowledge': 1,
#            'A1 <-> Stimulus <-> thing viewed': 1,
#            'A0 <-> Agent <-> grinder': 1,
#            'A4 <-> secondary attribute on arg1': 1,
#            'A1 <-> Theme <-> entity selected': 2,
#            'A0 <-> Pivot <-> speaker, revealer': 1,
#            'A1 <-> Topic <-> utterance, truth condition': 1,
#            'A1 <-> Theme <-> favor': 1,
#            'A3 <-> purpose': 2,
#            'A1 <-> Patient <-> figure': 1,
#            'A2 <-> ground': 1,
#            'R-A1 <-> Theme <-> thing thrown': 1,
#            'A2 <-> Destination <-> destination': 4,
#            'A2 <-> Destination': 1,
#            'A1 <-> Theme <-> Theme (action or object being stopped)': 1,
#            'A1 <-> Theme <-> thing thrown': 2,
#            'A0 <-> Agent <-> causer of vibration (rare)': 1,
#            'A2 <-> Predicate': 1,
#            'A1 <-> Theme <-> used': 1,
#            'A2 <-> Predicate <-> job, purpose': 1,
#            'A1 <-> Topic <-> item': 1,
#            'A1 <-> Agent <-> thing changing': 2,
#            'R-A0 <-> Theme <-> container': 1,
#            'R-A1 <-> Topic <-> thing reported': 1,
#            'A0 <-> Pivot': 1,
#            'A1 <-> Theme <-> thing taken': 2,
#            'A2 <-> taken FROM, SOURCE of thing taken': 1,
#            'A1 <-> Theme <-> belief': 1,
#            'C-A1 <-> Theme <-> belief': 1,
#            'A1 <-> Patient <-> thing(s) being divided': 1,
#            'A2 <-> divided among (resulting/destination groups)': 1,
#            'A3 <-> Value <-> measurement': 1,
#            'A1 <-> Theme <-> impelled action': 1,
#            'A0 <-> Causer <-> forcer, causer': 1,
#            'A1 <-> Patient <-> thing set': 1,
#            'A0 <-> Agent <-> agent, setter': 1,
#            'A1 <-> Theme <-> signified': 2,
#            'A2 <-> ingredient two': 1,
#            'R-A0 <-> Agent <-> exhibiter': 1,
#            'R-A0 <-> Agent <-> measurer': 1,
#            'A2 <-> Attribute <-> source': 1,
#            'A0 <-> Agent <-> causer of non-association, agent': 1,
#            'R-A0 <-> Agent <-> causer of non-association, agent': 1,
#            'A1 <-> Patient <-> thing not associated': 1,
#            'A2 <-> Co Patient <-> separated from': 1,
#            'R-A1 <-> Source <-> entity peeled': 1,
#            'A1 <-> Experiencer <-> refreshed entity': 1,
#            'A2 <-> Result <-> end state, attribute of arg1': 1,
#            'A1 <-> Theme <-> thing spinning': 1,
#            'A4 <-> Destination': 1,
#            'A1 <-> Patient <-> thing combusting': 1,
#            'A1 <-> Patient <-> original': 1,
#            'A2 <-> copy': 1,
#            'A2 <-> adjusted to; goal state; outside situation that arg1 is wanted to match': 1,
#            'C-A1 <-> Topic <-> thing reported': 1,
#            'A2 <-> Source <-> procured from': 1,
#            'A2 <-> benefactive/attribute of Arg1': 1,
#            'A0 <-> Stimulus <-> agent, stirrer': 1,
#            'A1 <-> Stimulus <-> noticed': 1,
#            'A0 <-> Agent <-> entity losing something': 1,
#            'A1 <-> Theme <-> thing lost': 1,
#            'A1 <-> Theme <-> group': 1,
#            'A2 <-> parts or members': 1,
#            'A2 <-> Theme <-> illness or injury': 1,
#            'A1 <-> Destination <-> item being labelled': 1,
#            'A2 <-> attribute, label itself': 1}),
#   'n_sentences': 1308}}

# %%
stats_dict["wsj"]["n_sentences"], stats_dict["wsj"]["vn_roles"].most_common(10)
# Out:
# (37015,
#  [('Theme', 59135),
#   ('Agent', 48654),
#   ('', 17984),
#   ('Patient', 14213),
#   ('Topic', 12440),
#   ('Attribute', 12178),
#   ('Experiencer', 5181),
#   ('Stimulus', 5065),
#   ('Pivot', 4277),
#   ('Result', 3137)])

# %%
stats_dict["risec"]["n_sentences"], stats_dict["risec"]["vn_roles"].most_common(10)
# Out:
# (1189,
#  [('Theme', 424),
#   ('Patient', 367),
#   ('Destination', 216),
#   ('', 106),
#   ('Attribute', 46),
#   ('Initial Location', 43),
#   ('Experiencer', 31),
#   ('Result', 28),
#   ('Material', 28),
#   ('Agent', 24)])

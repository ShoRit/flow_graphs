# %%
# %load_ext autoreload
# %autoreload 2

# %%
from collections import defaultdict
import dill
import json
import pickle
from pprint import pprint

import amrlib
from amrlib import load_stog_model
from amrlib.graph_processing.amr_plot import AMRPlot
from amrlib.graph_processing.amr_loading import load_amr_entries
from amrlib.graph_processing.annotator import add_lemmas
from amrlib.alignments.rbw_aligner import RBWAligner
from amrlib.alignments.faa_aligner import FAA_Aligner
import penman
from penman.surface import Alignment
from transformers import AutoTokenizer

from annotate_datasets import *

# %%
amr_model = load_stog_model(device="cuda:0")

# %%
with open("/projects/flow_graphs/data/risec/train.json") as f:
    train_data = json.load(f)

# %%
train_data[1]["rels"]
# Out:
# [{'_id': 'R1',
#   'arg1_start': 3,
#   'arg1_end': 10,
#   'arg1_word': 'Preheat',
#   'arg1_label': 'AC',
#   'arg2_start': 11,
#   'arg2_end': 15,
#   'arg2_word': 'oven',
#   'arg2_label': 'TOOL',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R2',
#   'arg1_start': 3,
#   'arg1_end': 10,
#   'arg1_word': 'Preheat',
#   'arg1_label': 'AC',
#   'arg2_start': 19,
#   'arg2_end': 32,
#   'arg2_word': '350 degrees F',
#   'arg2_label': 'TEMPERATURE',
#   'arg_label': 'ArgM_MNR'},
#  {'_id': 'R3',
#   'arg1_start': 3,
#   'arg1_end': 10,
#   'arg1_word': 'Preheat',
#   'arg1_label': 'AC',
#   'arg2_start': 34,
#   'arg2_end': 47,
#   'arg2_word': '175 degrees C',
#   'arg2_label': 'TEMPERATURE',
#   'arg_label': 'ArgM_MNR'},
#  {'_id': 'R4',
#   'arg1_start': 53,
#   'arg1_end': 59,
#   'arg1_word': 'Grease',
#   'arg1_label': 'AC',
#   'arg2_start': 60,
#   'arg2_end': 81,
#   'arg2_word': 'one 9x5 inch loaf pan',
#   'arg2_label': 'TOOL',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R5',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 94,
#   'arg2_end': 99,
#   'arg2_word': 'flour',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R6',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 101,
#   'arg2_end': 112,
#   'arg2_word': '1 cup sugar',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R7',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 114,
#   'arg2_end': 127,
#   'arg2_word': 'baking powder',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R8',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 129,
#   'arg2_end': 140,
#   'arg2_word': 'baking soda',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R9',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 142,
#   'arg2_end': 166,
#   'arg2_word': '1 1/2 teaspoons cinnamon',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R10',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 168,
#   'arg2_end': 172,
#   'arg2_word': 'salt',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R11',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 174,
#   'arg2_end': 184,
#   'arg2_word': 'buttermilk',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R12',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 186,
#   'arg2_end': 189,
#   'arg2_word': 'oil',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R13',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 191,
#   'arg2_end': 195,
#   'arg2_word': 'eggs',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R14',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 200,
#   'arg2_end': 207,
#   'arg2_word': 'vanilla',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R15',
#   'arg1_start': 86,
#   'arg1_end': 93,
#   'arg1_word': 'Measure',
#   'arg1_label': 'AC',
#   'arg2_start': 213,
#   'arg2_end': 230,
#   'arg2_word': 'large mixing bowl',
#   'arg2_label': 'TOOL',
#   'arg_label': 'Arg_GOL'},
#  {'_id': 'R16',
#   'arg1_start': 235,
#   'arg1_end': 239,
#   'arg1_word': 'Beat',
#   'arg1_label': 'AC',
#   'arg2_start': 240,
#   'arg2_end': 249,
#   'arg2_word': '3 minutes',
#   'arg2_label': 'DUR',
#   'arg_label': 'ArgM_TMP'},
#  {'_id': 'R17',
#   'arg1_start': 254,
#   'arg1_end': 258,
#   'arg1_word': 'Pour',
#   'arg1_label': 'AC',
#   'arg2_start': 264,
#   'arg2_end': 281,
#   'arg2_word': 'prepared loaf pan',
#   'arg2_label': 'TOOL',
#   'arg_label': 'Arg_GOL'},
#  {'_id': 'R18',
#   'arg1_start': 254,
#   'arg1_end': 258,
#   'arg1_word': 'Pour',
#   'arg1_label': 'AC',
#   'arg2_start': 235,
#   'arg2_end': 239,
#   'arg2_word': 'Beat',
#   'arg2_label': 'AC',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R19',
#   'arg1_start': 286,
#   'arg1_end': 292,
#   'arg1_word': 'Smooth',
#   'arg1_label': 'AC',
#   'arg2_start': 293,
#   'arg2_end': 296,
#   'arg2_word': 'top',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R20',
#   'arg1_start': 301,
#   'arg1_end': 308,
#   'arg1_word': 'Combine',
#   'arg1_label': 'AC',
#   'arg2_start': 309,
#   'arg2_end': 334,
#   'arg2_word': '2 tablespoons white sugar',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R21',
#   'arg1_start': 301,
#   'arg1_end': 308,
#   'arg1_word': 'Combine',
#   'arg1_label': 'AC',
#   'arg2_start': 336,
#   'arg2_end': 355,
#   'arg2_word': '1 teaspoon cinnamon',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R22',
#   'arg1_start': 301,
#   'arg1_end': 308,
#   'arg1_word': 'Combine',
#   'arg1_label': 'AC',
#   'arg2_start': 360,
#   'arg2_end': 366,
#   'arg2_word': 'butter',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R23',
#   'arg1_start': 301,
#   'arg1_end': 308,
#   'arg1_word': 'Combine',
#   'arg1_label': 'AC',
#   'arg2_start': 368,
#   'arg2_end': 374,
#   'arg2_word': 'mixing',
#   'arg2_label': 'AC',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R24',
#   'arg1_start': 368,
#   'arg1_end': 374,
#   'arg1_word': 'mixing',
#   'arg1_label': 'AC',
#   'arg2_start': 375,
#   'arg2_end': 388,
#   'arg2_word': 'until crumbly',
#   'arg2_label': 'CONDITION_CLAUSE',
#   'arg_label': 'ArgM_TMP'},
#  {'_id': 'R25',
#   'arg1_start': 393,
#   'arg1_end': 401,
#   'arg1_word': 'Sprinkle',
#   'arg1_label': 'AC',
#   'arg2_start': 402,
#   'arg2_end': 409,
#   'arg2_word': 'topping',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R26',
#   'arg1_start': 393,
#   'arg1_end': 401,
#   'arg1_word': 'Sprinkle',
#   'arg1_label': 'AC',
#   'arg2_start': 415,
#   'arg2_end': 430,
#   'arg2_word': 'smoothed batter',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_GOL'},
#  {'_id': 'R28',
#   'arg1_start': 448,
#   'arg1_end': 451,
#   'arg1_word': 'cut',
#   'arg1_label': 'AC',
#   'arg2_start': 455,
#   'arg2_end': 478,
#   'arg2_word': 'a light swirling motion',
#   'arg2_label': 'OTHER',
#   'arg_label': 'ArgM_MNR'},
#  {'_id': 'R30',
#   'arg1_start': 509,
#   'arg1_end': 513,
#   'arg1_word': 'Bake',
#   'arg1_label': 'AC',
#   'arg2_start': 524,
#   'arg2_end': 534,
#   'arg2_word': '50 minutes',
#   'arg2_label': 'DUR',
#   'arg_label': 'ArgM_TMP'},
#  {'_id': 'R31',
#   'arg1_start': 540,
#   'arg1_end': 544,
#   'arg1_word': 'Test',
#   'arg1_label': 'AC',
#   'arg2_start': 550,
#   'arg2_end': 559,
#   'arg2_word': 'toothpick',
#   'arg2_label': 'TOOL',
#   'arg_label': 'ArgM_INT'},
#  {'_id': 'R32',
#   'arg1_start': 589,
#   'arg1_end': 593,
#   'arg1_word': 'come',
#   'arg1_label': 'AC',
#   'arg2_start': 579,
#   'arg2_end': 581,
#   'arg2_word': 'it',
#   'arg2_label': 'TOOL',
#   'arg_label': 'Arg_PAG'},
#  {'_id': 'R33',
#   'arg1_start': 609,
#   'arg1_end': 615,
#   'arg1_word': 'Remove',
#   'arg1_label': 'AC',
#   'arg2_start': 616,
#   'arg2_end': 621,
#   'arg2_word': 'bread',
#   'arg2_label': 'FOOD',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R34',
#   'arg1_start': 609,
#   'arg1_end': 615,
#   'arg1_word': 'Remove',
#   'arg1_label': 'AC',
#   'arg2_start': 627,
#   'arg2_end': 630,
#   'arg2_word': 'pan',
#   'arg2_label': 'TOOL',
#   'arg_label': 'Arg_DIR'},
#  {'_id': 'R35',
#   'arg1_start': 609,
#   'arg1_end': 615,
#   'arg1_word': 'Remove',
#   'arg1_label': 'AC',
#   'arg2_start': 634,
#   'arg2_end': 638,
#   'arg2_word': 'rack',
#   'arg2_label': 'TOOL',
#   'arg_label': 'Arg_GOL'},
#  {'_id': 'R36',
#   'arg1_start': 609,
#   'arg1_end': 615,
#   'arg1_word': 'Remove',
#   'arg1_label': 'AC',
#   'arg2_start': 639,
#   'arg2_end': 646,
#   'arg2_word': 'to cool',
#   'arg2_label': 'PURPOSE_CLAUSE',
#   'arg_label': 'ArgM_PRP'},
#  {'_id': 'R37',
#   'arg1_start': 540,
#   'arg1_end': 544,
#   'arg1_word': 'Test',
#   'arg1_label': 'AC',
#   'arg2_start': 509,
#   'arg2_end': 513,
#   'arg2_word': 'Bake',
#   'arg2_label': 'AC',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R38',
#   'arg1_start': 509,
#   'arg1_end': 513,
#   'arg1_word': 'Bake',
#   'arg1_label': 'AC',
#   'arg2_start': 448,
#   'arg2_end': 451,
#   'arg2_word': 'cut',
#   'arg2_label': 'AC',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R39',
#   'arg1_start': 235,
#   'arg1_end': 239,
#   'arg1_word': 'Beat',
#   'arg1_label': 'AC',
#   'arg2_start': 86,
#   'arg2_end': 93,
#   'arg2_word': 'Measure',
#   'arg2_label': 'AC',
#   'arg_label': 'Arg_PPT'},
#  {'_id': 'R40',
#   'arg1_start': 589,
#   'arg1_end': 593,
#   'arg1_word': 'come',
#   'arg1_label': 'AC',
#   'arg2_start': 565,
#   'arg2_end': 578,
#   'arg2_word': 'When inserted',
#   'arg2_label': 'CONDITION_CLAUSE',
#   'arg_label': 'ArgM_TMP'},
#  {'_id': 'R27',
#   'arg1_start': 448,
#   'arg1_end': 451,
#   'arg1_word': 'cut',
#   'arg1_label': 'AC',
#   'arg2_start': 441,
#   'arg2_end': 446,
#   'arg2_word': 'knife',
#   'arg2_label': 'TOOL',
#   'arg_label': 'ArgM_INT'},
#  {'_id': 'R29',
#   'arg1_start': 448,
#   'arg1_end': 451,
#   'arg1_word': 'cut',
#   'arg1_label': 'AC',
#   'arg2_start': 479,
#   'arg2_end': 503,
#   'arg2_word': 'to give a marbled effect',
#   'arg2_label': 'PURPOSE_CLAUSE',
#   'arg_label': 'ArgM_PRP'}]

# %%
split_sentences = sentencizer(train_data[0]["text"])

# %%
graphs, sentences, tokens = annotate_sentences(train_data[0]["text"], amr_model, None)
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 5/5 [00:01<00:00,  3.20it/s]

# %%
sentences[0]
# Out:
# '1) In a saucepan over low heat, stir together the half-and-half and sugar.'

# %%
penman.decode(graphs[0]).triples
# Out:
# [('z1', ':instance', 'stir-01'),
#  ('z1', ':li', '1'),
#  ('z1', ':arg0', 'z2'),
#  ('z2', ':instance', 'you'),
#  ('z1', ':arg1', 'z3'),
#  ('z3', ':instance', 'and'),
#  ('z3', ':op1', 'z4'),
#  ('z4', ':instance', 'half-and-half'),
#  ('z3', ':op2', 'z5'),
#  ('z5', ':instance', 'sugar'),
#  ('z1', ':mod', 'z6'),
#  ('z6', ':instance', 'together'),
#  ('z1', ':location', 'z7'),
#  ('z7', ':instance', 'saucepan'),
#  ('z8', ':location', 'z7'),
#  ('z8', ':instance', 'heat'),
#  ('z9', ':arg1', 'z8'),
#  ('z9', ':instance', 'low-04')]

# %%
tokens[0]
# Out:
# [PenmanToken(token_str='1)', start_idx=0, end_idx=2),
#  PenmanToken(token_str='In', start_idx=3, end_idx=5),
#  PenmanToken(token_str='a', start_idx=6, end_idx=7),
#  PenmanToken(token_str='saucepan', start_idx=8, end_idx=16),
#  PenmanToken(token_str='over', start_idx=17, end_idx=21),
#  PenmanToken(token_str='low', start_idx=22, end_idx=25),
#  PenmanToken(token_str='heat,', start_idx=26, end_idx=31),
#  PenmanToken(token_str='stir', start_idx=32, end_idx=36),
#  PenmanToken(token_str='together', start_idx=37, end_idx=45),
#  PenmanToken(token_str='the', start_idx=46, end_idx=49),
#  PenmanToken(token_str='half-and-half', start_idx=50, end_idx=63),
#  PenmanToken(token_str='and', start_idx=64, end_idx=67),
#  PenmanToken(token_str='sugar.', start_idx=68, end_idx=74)]

# %%
alignments = penman.surface.alignments(penman.decode(graphs[0]))

# %%
a = alignments[('z1', ':instance', 'stir-01')]
a.indices[0]
# Out:
# 7

# %%
tokens
# Out:
# [[PenmanToken(token_str='1)', start_idx=0, end_idx=2),
#   PenmanToken(token_str='In', start_idx=3, end_idx=5),
#   PenmanToken(token_str='a', start_idx=6, end_idx=7),
#   PenmanToken(token_str='saucepan', start_idx=8, end_idx=16),
#   PenmanToken(token_str='over', start_idx=17, end_idx=21),
#   PenmanToken(token_str='low', start_idx=22, end_idx=25),
#   PenmanToken(token_str='heat,', start_idx=26, end_idx=31),
#   PenmanToken(token_str='stir', start_idx=32, end_idx=36),
#   PenmanToken(token_str='together', start_idx=37, end_idx=45),
#   PenmanToken(token_str='the', start_idx=46, end_idx=49),
#   PenmanToken(token_str='half-and-half', start_idx=50, end_idx=63),
#   PenmanToken(token_str='and', start_idx=64, end_idx=67),
#   PenmanToken(token_str='sugar.', start_idx=68, end_idx=74)],
#  [PenmanToken(token_str='', start_idx=0, end_idx=0),
#   PenmanToken(token_str='2)', start_idx=1, end_idx=3),
#   PenmanToken(token_str='Whisk', start_idx=4, end_idx=9),
#   PenmanToken(token_str='in', start_idx=10, end_idx=12),
#   PenmanToken(token_str='egg', start_idx=13, end_idx=16),
#   PenmanToken(token_str='yolks', start_idx=17, end_idx=22),
#   PenmanToken(token_str='and', start_idx=23, end_idx=26),
#   PenmanToken(token_str='cook', start_idx=27, end_idx=31),
#   PenmanToken(token_str='until', start_idx=32, end_idx=37),
#   PenmanToken(token_str='light', start_idx=38, end_idx=43),
#   PenmanToken(token_str='custard', start_idx=44, end_idx=51),
#   PenmanToken(token_str='forms;', start_idx=52, end_idx=58),
#   PenmanToken(token_str='do', start_idx=59, end_idx=61),
#   PenmanToken(token_str='not', start_idx=62, end_idx=65),
#   PenmanToken(token_str='boil.', start_idx=66, end_idx=71)],
#  [PenmanToken(token_str='', start_idx=0, end_idx=0),
#   PenmanToken(token_str='3)', start_idx=1, end_idx=3),
#   PenmanToken(token_str='Remove', start_idx=4, end_idx=10),
#   PenmanToken(token_str='from', start_idx=11, end_idx=15),
#   PenmanToken(token_str='heat', start_idx=16, end_idx=20),
#   PenmanToken(token_str='and', start_idx=21, end_idx=24),
#   PenmanToken(token_str='cool,', start_idx=25, end_idx=30),
#   PenmanToken(token_str='then', start_idx=31, end_idx=35),
#   PenmanToken(token_str='place', start_idx=36, end_idx=41),
#   PenmanToken(token_str='in', start_idx=42, end_idx=44),
#   PenmanToken(token_str='refrigerator', start_idx=45, end_idx=57),
#   PenmanToken(token_str='and', start_idx=58, end_idx=61),
#   PenmanToken(token_str='chill', start_idx=62, end_idx=67),
#   PenmanToken(token_str='overnight.', start_idx=68, end_idx=78)],
#  [PenmanToken(token_str='', start_idx=0, end_idx=0),
#   PenmanToken(token_str='4)', start_idx=1, end_idx=3),
#   PenmanToken(token_str='Into', start_idx=4, end_idx=8),
#   PenmanToken(token_str='the', start_idx=9, end_idx=12),
#   PenmanToken(token_str='chilled', start_idx=13, end_idx=20),
#   PenmanToken(token_str='mixture,', start_idx=21, end_idx=29),
#   PenmanToken(token_str='stir', start_idx=30, end_idx=34),
#   PenmanToken(token_str='in', start_idx=35, end_idx=37),
#   PenmanToken(token_str='vanilla,', start_idx=38, end_idx=46),
#   PenmanToken(token_str='cream,', start_idx=47, end_idx=53),
#   PenmanToken(token_str='dark', start_idx=54, end_idx=58),
#   PenmanToken(token_str='rum,', start_idx=59, end_idx=63),
#   PenmanToken(token_str='scotch,', start_idx=64, end_idx=71),
#   PenmanToken(token_str='and', start_idx=72, end_idx=75),
#   PenmanToken(token_str='vanilla', start_idx=76, end_idx=83),
#   PenmanToken(token_str='ice', start_idx=84, end_idx=87),
#   PenmanToken(token_str='cream.', start_idx=88, end_idx=94),
#   PenmanToken(token_str='5)', start_idx=95, end_idx=97),
#   PenmanToken(token_str='Serve', start_idx=98, end_idx=103),
#   PenmanToken(token_str='cold.', start_idx=104, end_idx=109)],
#  [PenmanToken(token_str='', start_idx=0, end_idx=0),
#   PenmanToken(token_str='', start_idx=0, end_idx=0)]]

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# %%
offset_mapping = tokenizer(sentences[0], return_offsets_mapping=True, max_length=512)["offset_mapping"]

# %%
offset_mapping[1:-1]
# Out:
# [(0, 1),
#  (1, 2),
#  (3, 5),
#  (6, 7),
#  (8, 13),
#  (13, 16),
#  (17, 21),
#  (22, 25),
#  (26, 30),
#  (30, 31),
#  (32, 36),
#  (37, 45),
#  (46, 49),
#  (50, 54),
#  (54, 55),
#  (55, 58),
#  (58, 59),
#  (59, 63),
#  (64, 67),
#  (68, 73),
#  (73, 74)]

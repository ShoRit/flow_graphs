# %%
import os

import numpy as np
from sklearn.metrics import precision_recall_fscore_support
import torch
from torch.utils.data import Dataset, DataLoader
from tqdm.auto import tqdm
from transformers import BertConfig


from dataloading_utils import load_dataset, load_deprels
from dataloader import get_data_loaders
from modeling.bert import BertRGCNRelationClassifierResidual

# %%
eval_dataset = "mscorpus"
base_path = "/projects/flow_graphs/"
batch_size = 16
graph_data_source = "dep"
max_seq_len = 512
bert_model = "bert-base-uncased"
gnn = "rgcn"
gnn_depth = 4
node_emb_dim =  768
device = "cuda:0"

# %%
dataset = load_dataset(base_path, eval_dataset)

# %%
train_data = dataset["train"]["rels"]
dev_data = dataset["dev"]["rels"]
test_data = dataset["test"]["rels"]

deprel_dict = load_deprels(
    path=os.path.join(base_path, "data", "enh_dep_rel.txt"), enhanced=False
)

print(
    "train size: {}, dev size {}, test size: {}".format(
        len(train_data), len(dev_data), len(test_data)
    )
)

src_labels = set([data["label"] for data in dataset["train"]["rels"]])
train_labels = [data["label"] for data in train_data]
labels = sorted(list(set(train_labels)))
lbl2id = {lbl: idx for idx, lbl in enumerate(labels)}
# Out:
# 100%|██████████| 365/365 [00:00<00:00, 502270.66it/s]
# train size: 12330, dev size 2287, test size: 3782

# %%
train_loader, dev_loader, test_loader = get_data_loaders(
    train_data,
    dev_data,
    test_data,
    lbl2id,
    graph_data_source,
    max_seq_len,
    batch_size,
)

# %%
bertconfig = BertConfig.from_pretrained(bert_model, num_labels=len(labels))
if "bert-large" in bert_model:
    bertconfig.relation_emb_dim = 1024
elif "bert-base" in bert_model:
    bertconfig.relation_emb_dim = 768

bertconfig.node_emb_dim = node_emb_dim
bertconfig.dep_rels = len(deprel_dict)
bertconfig.gnn_depth = gnn_depth
bertconfig.gnn = gnn

# %%
checkpoint_file = "/projects/flow_graphs/checkpoints/transfer-risec-mscorpus-fewshot_0.01-dep_residual-residual-rgcn-depth_4-seed_1-lr_2e-05.pt"
state_dict = torch.load(checkpoint_file)

# %%
model = BertRGCNRelationClassifierResidual.from_pretrained(bert_model, config=bertconfig, use_graph_data=True)
model.load_state_dict(state_dict)
model.eval()
model.to(device)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertRGCNRelationClassifierResidual: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertRGCNRelationClassifierResidual from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertRGCNRelationClassifierResidual from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertRGCNRelationClassifierResidual were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['gnn.rgcn_module.3.gnn.weight', 'gnn.rgcn_module.3.gnn.bias', 'gnn.rgcn_module.0.gnn.bias', 'fc_layer.weight', 'gnn.rgcn_module.6.gnn.bias', 'rel_classifier.weight', 'gnn.rgcn_module.6.gnn.root', 'gnn.rgcn_module.6.gnn.weight', 'gnn.rgcn_module.0.gnn.root', 'rel_classifier.bias', 'gnn.rgcn_module.9.gnn.weight', 'gnn.rgcn_module.9.gnn.bias', 'gnn.rgcn_module.0.gnn.weight', 'gnn.rgcn_module.3.gnn.root', 'gnn.rgcn_module.9.gnn.root', 'fc_layer.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertRGCNRelationClassifierResidual(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (gnn): DeepNet(
#     (rgcn_module): Sequential(
#       (0): GNNConv(
#         (gnn): RGCNConv(768, 768, num_relations=38)
#       )
#       (1): GNNReLu(
#         (relu): ReLU()
#       )
#       (2): GNNDropout(
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (3): GNNConv(
#         (gnn): RGCNConv(768, 768, num_relations=38)
#       )
#       (4): GNNReLu(
#         (relu): ReLU()
#       )
#       (5): GNNDropout(
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (6): GNNConv(
#         (gnn): RGCNConv(768, 768, num_relations=38)
#       )
#       (7): GNNReLu(
#         (relu): ReLU()
#       )
#       (8): GNNDropout(
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (9): GNNConv(
#         (gnn): RGCNConv(768, 768, num_relations=38)
#       )
#       (10): GNNReLu(
#         (relu): ReLU()
#       )
#     )
#   )
#   (loss_fn): CrossEntropyLoss()
#   (fc_layer): Linear(in_features=2304, out_features=768, bias=True)
#   (rel_classifier): Linear(in_features=768, out_features=11, bias=True)
# )

# %%
y_true = []
y_pred = []

for data in tqdm(dev_loader):
    tokens_tensors = data["tokens_tensors"].to(device)
    segments_tensors = data["segments_tensors"].to(device)
    e1_mask = data["e1_mask"].to(device)
    e2_mask = data["e2_mask"].to(device)
    masks_tensors = data["masks_tensors"].to(device)
    labels = data["label_ids"].to(device)

    if data["graph_data"] is not None:
        graph_data = data["graph_data"].to(device)
    else:
        graph_data = None

    print(graph_data)

    with torch.no_grad():
        output_dict = model(
            input_ids=tokens_tensors,
            token_type_ids=segments_tensors,
            e1_mask=e1_mask,
            e2_mask=e2_mask,
            attention_mask=masks_tensors,
            labels=labels,
            graph_data=graph_data,
                    # can optionally pass in dependency/amr tensors if we want to use both.
        )

    _, pred = torch.max(output_dict["logits"], 1)
    y_pred.extend(list(np.array(pred.cpu().detach())))
    y_true.extend(list(np.array(labels.cpu().detach())))
# Out:
#   0%|          | 0/143 [00:00<?, ?it/s]
# DataBatch(x=[663, 512], edge_index=[2, 647], edge_type=[647], n1_mask=[663], n2_mask=[663], batch=[663], ptr=[17])
# DataBatch(x=[579, 512], edge_index=[2, 563], edge_type=[563], n1_mask=[579], n2_mask=[579], batch=[579], ptr=[17])
# DataBatch(x=[671, 512], edge_index=[2, 655], edge_type=[655], n1_mask=[671], n2_mask=[671], batch=[671], ptr=[17])
# DataBatch(x=[554, 512], edge_index=[2, 538], edge_type=[538], n1_mask=[554], n2_mask=[554], batch=[554], ptr=[17])
# DataBatch(x=[512, 512], edge_index=[2, 496], edge_type=[496], n1_mask=[512], n2_mask=[512], batch=[512], ptr=[17])
# DataBatch(x=[1160, 512], edge_index=[2, 1144], edge_type=[1144], n1_mask=[1160], n2_mask=[1160], batch=[1160], ptr=[17])
# DataBatch(x=[594, 512], edge_index=[2, 578], edge_type=[578], n1_mask=[594], n2_mask=[594], batch=[594], ptr=[17])
# DataBatch(x=[610, 512], edge_index=[2, 594], edge_type=[594], n1_mask=[610], n2_mask=[610], batch=[610], ptr=[17])
# DataBatch(x=[704, 512], edge_index=[2, 688], edge_type=[688], n1_mask=[704], n2_mask=[704], batch=[704], ptr=[17])
# DataBatch(x=[874, 512], edge_index=[2, 858], edge_type=[858], n1_mask=[874], n2_mask=[874], batch=[874], ptr=[17])
# DataBatch(x=[530, 512], edge_index=[2, 514], edge_type=[514], n1_mask=[530], n2_mask=[530], batch=[530], ptr=[17])
# DataBatch(x=[740, 512], edge_index=[2, 724], edge_type=[724], n1_mask=[740], n2_mask=[740], batch=[740], ptr=[17])
# DataBatch(x=[1062, 512], edge_index=[2, 1046], edge_type=[1046], n1_mask=[1062], n2_mask=[1062], batch=[1062], ptr=[17])
# DataBatch(x=[656, 512], edge_index=[2, 640], edge_type=[640], n1_mask=[656], n2_mask=[656], batch=[656], ptr=[17])
# DataBatch(x=[722, 512], edge_index=[2, 706], edge_type=[706], n1_mask=[722], n2_mask=[722], batch=[722], ptr=[17])
# DataBatch(x=[738, 512], edge_index=[2, 722], edge_type=[722], n1_mask=[738], n2_mask=[738], batch=[738], ptr=[17])
# DataBatch(x=[960, 512], edge_index=[2, 944], edge_type=[944], n1_mask=[960], n2_mask=[960], batch=[960], ptr=[17])
# DataBatch(x=[602, 512], edge_index=[2, 586], edge_type=[586], n1_mask=[602], n2_mask=[602], batch=[602], ptr=[17])
# DataBatch(x=[570, 512], edge_index=[2, 554], edge_type=[554], n1_mask=[570], n2_mask=[570], batch=[570], ptr=[17])
# DataBatch(x=[839, 512], edge_index=[2, 823], edge_type=[823], n1_mask=[839], n2_mask=[839], batch=[839], ptr=[17])
# DataBatch(x=[621, 512], edge_index=[2, 605], edge_type=[605], n1_mask=[621], n2_mask=[621], batch=[621], ptr=[17])
# DataBatch(x=[580, 512], edge_index=[2, 564], edge_type=[564], n1_mask=[580], n2_mask=[580], batch=[580], ptr=[17])
# DataBatch(x=[620, 512], edge_index=[2, 604], edge_type=[604], n1_mask=[620], n2_mask=[620], batch=[620], ptr=[17])
# DataBatch(x=[632, 512], edge_index=[2, 616], edge_type=[616], n1_mask=[632], n2_mask=[632], batch=[632], ptr=[17])
# DataBatch(x=[535, 512], edge_index=[2, 519], edge_type=[519], n1_mask=[535], n2_mask=[535], batch=[535], ptr=[17])
# DataBatch(x=[468, 512], edge_index=[2, 452], edge_type=[452], n1_mask=[468], n2_mask=[468], batch=[468], ptr=[17])
# DataBatch(x=[671, 512], edge_index=[2, 655], edge_type=[655], n1_mask=[671], n2_mask=[671], batch=[671], ptr=[17])
# DataBatch(x=[553, 512], edge_index=[2, 537], edge_type=[537], n1_mask=[553], n2_mask=[553], batch=[553], ptr=[17])
# DataBatch(x=[522, 512], edge_index=[2, 506], edge_type=[506], n1_mask=[522], n2_mask=[522], batch=[522], ptr=[17])
# DataBatch(x=[513, 512], edge_index=[2, 497], edge_type=[497], n1_mask=[513], n2_mask=[513], batch=[513], ptr=[17])
# DataBatch(x=[785, 512], edge_index=[2, 769], edge_type=[769], n1_mask=[785], n2_mask=[785], batch=[785], ptr=[17])
# DataBatch(x=[551, 512], edge_index=[2, 535], edge_type=[535], n1_mask=[551], n2_mask=[551], batch=[551], ptr=[17])
# DataBatch(x=[487, 512], edge_index=[2, 471], edge_type=[471], n1_mask=[487], n2_mask=[487], batch=[487], ptr=[17])
# DataBatch(x=[834, 512], edge_index=[2, 818], edge_type=[818], n1_mask=[834], n2_mask=[834], batch=[834], ptr=[17])
# DataBatch(x=[1168, 512], edge_index=[2, 1152], edge_type=[1152], n1_mask=[1168], n2_mask=[1168], batch=[1168], ptr=[17])
# DataBatch(x=[614, 512], edge_index=[2, 598], edge_type=[598], n1_mask=[614], n2_mask=[614], batch=[614], ptr=[17])
# DataBatch(x=[560, 512], edge_index=[2, 544], edge_type=[544], n1_mask=[560], n2_mask=[560], batch=[560], ptr=[17])
# DataBatch(x=[566, 512], edge_index=[2, 550], edge_type=[550], n1_mask=[566], n2_mask=[566], batch=[566], ptr=[17])
# DataBatch(x=[501, 512], edge_index=[2, 485], edge_type=[485], n1_mask=[501], n2_mask=[501], batch=[501], ptr=[17])
# DataBatch(x=[750, 512], edge_index=[2, 734], edge_type=[734], n1_mask=[750], n2_mask=[750], batch=[750], ptr=[17])
# DataBatch(x=[433, 512], edge_index=[2, 417], edge_type=[417], n1_mask=[433], n2_mask=[433], batch=[433], ptr=[17])
# DataBatch(x=[370, 512], edge_index=[2, 354], edge_type=[354], n1_mask=[370], n2_mask=[370], batch=[370], ptr=[17])
# DataBatch(x=[491, 512], edge_index=[2, 475], edge_type=[475], n1_mask=[491], n2_mask=[491], batch=[491], ptr=[17])
# DataBatch(x=[829, 512], edge_index=[2, 813], edge_type=[813], n1_mask=[829], n2_mask=[829], batch=[829], ptr=[17])
# DataBatch(x=[1517, 512], edge_index=[2, 1501], edge_type=[1501], n1_mask=[1517], n2_mask=[1517], batch=[1517], ptr=[17])
# DataBatch(x=[1472, 512], edge_index=[2, 1456], edge_type=[1456], n1_mask=[1472], n2_mask=[1472], batch=[1472], ptr=[17])
# DataBatch(x=[1139, 512], edge_index=[2, 1123], edge_type=[1123], n1_mask=[1139], n2_mask=[1139], batch=[1139], ptr=[17])
# DataBatch(x=[935, 512], edge_index=[2, 919], edge_type=[919], n1_mask=[935], n2_mask=[935], batch=[935], ptr=[17])
# DataBatch(x=[1010, 512], edge_index=[2, 994], edge_type=[994], n1_mask=[1010], n2_mask=[1010], batch=[1010], ptr=[17])
# DataBatch(x=[660, 512], edge_index=[2, 644], edge_type=[644], n1_mask=[660], n2_mask=[660], batch=[660], ptr=[17])
# DataBatch(x=[679, 512], edge_index=[2, 663], edge_type=[663], n1_mask=[679], n2_mask=[679], batch=[679], ptr=[17])
# DataBatch(x=[591, 512], edge_index=[2, 575], edge_type=[575], n1_mask=[591], n2_mask=[591], batch=[591], ptr=[17])
# DataBatch(x=[582, 512], edge_index=[2, 566], edge_type=[566], n1_mask=[582], n2_mask=[582], batch=[582], ptr=[17])
# DataBatch(x=[498, 512], edge_index=[2, 482], edge_type=[482], n1_mask=[498], n2_mask=[498], batch=[498], ptr=[17])
# DataBatch(x=[473, 512], edge_index=[2, 457], edge_type=[457], n1_mask=[473], n2_mask=[473], batch=[473], ptr=[17])
# DataBatch(x=[561, 512], edge_index=[2, 545], edge_type=[545], n1_mask=[561], n2_mask=[561], batch=[561], ptr=[17])
# DataBatch(x=[554, 512], edge_index=[2, 538], edge_type=[538], n1_mask=[554], n2_mask=[554], batch=[554], ptr=[17])
# DataBatch(x=[778, 512], edge_index=[2, 762], edge_type=[762], n1_mask=[778], n2_mask=[778], batch=[778], ptr=[17])
# DataBatch(x=[964, 512], edge_index=[2, 948], edge_type=[948], n1_mask=[964], n2_mask=[964], batch=[964], ptr=[17])
# DataBatch(x=[850, 512], edge_index=[2, 834], edge_type=[834], n1_mask=[850], n2_mask=[850], batch=[850], ptr=[17])
# DataBatch(x=[591, 512], edge_index=[2, 575], edge_type=[575], n1_mask=[591], n2_mask=[591], batch=[591], ptr=[17])
# DataBatch(x=[509, 512], edge_index=[2, 493], edge_type=[493], n1_mask=[509], n2_mask=[509], batch=[509], ptr=[17])
# DataBatch(x=[1355, 512], edge_index=[2, 1339], edge_type=[1339], n1_mask=[1355], n2_mask=[1355], batch=[1355], ptr=[17])
# DataBatch(x=[1709, 512], edge_index=[2, 1693], edge_type=[1693], n1_mask=[1709], n2_mask=[1709], batch=[1709], ptr=[17])
# DataBatch(x=[1421, 512], edge_index=[2, 1405], edge_type=[1405], n1_mask=[1421], n2_mask=[1421], batch=[1421], ptr=[17])
# DataBatch(x=[1248, 512], edge_index=[2, 1232], edge_type=[1232], n1_mask=[1248], n2_mask=[1248], batch=[1248], ptr=[17])
# DataBatch(x=[896, 512], edge_index=[2, 880], edge_type=[880], n1_mask=[896], n2_mask=[896], batch=[896], ptr=[17])
# DataBatch(x=[1055, 512], edge_index=[2, 1039], edge_type=[1039], n1_mask=[1055], n2_mask=[1055], batch=[1055], ptr=[17])
# DataBatch(x=[785, 512], edge_index=[2, 769], edge_type=[769], n1_mask=[785], n2_mask=[785], batch=[785], ptr=[17])
# DataBatch(x=[883, 512], edge_index=[2, 867], edge_type=[867], n1_mask=[883], n2_mask=[883], batch=[883], ptr=[17])
# DataBatch(x=[1088, 512], edge_index=[2, 1072], edge_type=[1072], n1_mask=[1088], n2_mask=[1088], batch=[1088], ptr=[17])
# DataBatch(x=[897, 512], edge_index=[2, 881], edge_type=[881], n1_mask=[897], n2_mask=[897], batch=[897], ptr=[17])
# DataBatch(x=[778, 512], edge_index=[2, 762], edge_type=[762], n1_mask=[778], n2_mask=[778], batch=[778], ptr=[17])
# DataBatch(x=[1140, 512], edge_index=[2, 1124], edge_type=[1124], n1_mask=[1140], n2_mask=[1140], batch=[1140], ptr=[17])
# DataBatch(x=[1226, 512], edge_index=[2, 1210], edge_type=[1210], n1_mask=[1226], n2_mask=[1226], batch=[1226], ptr=[17])
# DataBatch(x=[1104, 512], edge_index=[2, 1088], edge_type=[1088], n1_mask=[1104], n2_mask=[1104], batch=[1104], ptr=[17])
# DataBatch(x=[840, 512], edge_index=[2, 824], edge_type=[824], n1_mask=[840], n2_mask=[840], batch=[840], ptr=[17])
# DataBatch(x=[712, 512], edge_index=[2, 696], edge_type=[696], n1_mask=[712], n2_mask=[712], batch=[712], ptr=[17])
# DataBatch(x=[955, 512], edge_index=[2, 939], edge_type=[939], n1_mask=[955], n2_mask=[955], batch=[955], ptr=[17])
# DataBatch(x=[1251, 512], edge_index=[2, 1235], edge_type=[1235], n1_mask=[1251], n2_mask=[1251], batch=[1251], ptr=[17])
# DataBatch(x=[2896, 512], edge_index=[2, 2880], edge_type=[2880], n1_mask=[2896], n2_mask=[2896], batch=[2896], ptr=[17])
# DataBatch(x=[2896, 512], edge_index=[2, 2880], edge_type=[2880], n1_mask=[2896], n2_mask=[2896], batch=[2896], ptr=[17])
# DataBatch(x=[3090, 512], edge_index=[2, 3074], edge_type=[3074], n1_mask=[3090], n2_mask=[3090], batch=[3090], ptr=[17])
# DataBatch(x=[1568, 512], edge_index=[2, 1552], edge_type=[1552], n1_mask=[1568], n2_mask=[1568], batch=[1568], ptr=[17])
# DataBatch(x=[1568, 512], edge_index=[2, 1552], edge_type=[1552], n1_mask=[1568], n2_mask=[1568], batch=[1568], ptr=[17])
# DataBatch(x=[902, 512], edge_index=[2, 886], edge_type=[886], n1_mask=[902], n2_mask=[902], batch=[902], ptr=[17])
# DataBatch(x=[2166, 512], edge_index=[2, 2150], edge_type=[2150], n1_mask=[2166], n2_mask=[2166], batch=[2166], ptr=[17])
# DataBatch(x=[2144, 512], edge_index=[2, 2128], edge_type=[2128], n1_mask=[2144], n2_mask=[2144], batch=[2144], ptr=[17])
# DataBatch(x=[1986, 512], edge_index=[2, 1970], edge_type=[1970], n1_mask=[1986], n2_mask=[1986], batch=[1986], ptr=[17])
# DataBatch(x=[905, 512], edge_index=[2, 889], edge_type=[889], n1_mask=[905], n2_mask=[905], batch=[905], ptr=[17])
# DataBatch(x=[656, 512], edge_index=[2, 640], edge_type=[640], n1_mask=[656], n2_mask=[656], batch=[656], ptr=[17])
# DataBatch(x=[816, 512], edge_index=[2, 800], edge_type=[800], n1_mask=[816], n2_mask=[816], batch=[816], ptr=[17])
# DataBatch(x=[738, 512], edge_index=[2, 722], edge_type=[722], n1_mask=[738], n2_mask=[738], batch=[738], ptr=[17])
# DataBatch(x=[898, 512], edge_index=[2, 882], edge_type=[882], n1_mask=[898], n2_mask=[898], batch=[898], ptr=[17])
# DataBatch(x=[1360, 512], edge_index=[2, 1344], edge_type=[1344], n1_mask=[1360], n2_mask=[1360], batch=[1360], ptr=[17])
# DataBatch(x=[1386, 512], edge_index=[2, 1370], edge_type=[1370], n1_mask=[1386], n2_mask=[1386], batch=[1386], ptr=[17])
# DataBatch(x=[1320, 512], edge_index=[2, 1304], edge_type=[1304], n1_mask=[1320], n2_mask=[1320], batch=[1320], ptr=[17])
# DataBatch(x=[885, 512], edge_index=[2, 869], edge_type=[869], n1_mask=[885], n2_mask=[885], batch=[885], ptr=[17])
# DataBatch(x=[418, 512], edge_index=[2, 402], edge_type=[402], n1_mask=[418], n2_mask=[418], batch=[418], ptr=[17])
# DataBatch(x=[736, 512], edge_index=[2, 720], edge_type=[720], n1_mask=[736], n2_mask=[736], batch=[736], ptr=[17])
# DataBatch(x=[846, 512], edge_index=[2, 830], edge_type=[830], n1_mask=[846], n2_mask=[846], batch=[846], ptr=[17])
# DataBatch(x=[653, 512], edge_index=[2, 637], edge_type=[637], n1_mask=[653], n2_mask=[653], batch=[653], ptr=[17])
# DataBatch(x=[932, 512], edge_index=[2, 916], edge_type=[916], n1_mask=[932], n2_mask=[932], batch=[932], ptr=[17])
# DataBatch(x=[721, 512], edge_index=[2, 705], edge_type=[705], n1_mask=[721], n2_mask=[721], batch=[721], ptr=[17])
# DataBatch(x=[1008, 512], edge_index=[2, 992], edge_type=[992], n1_mask=[1008], n2_mask=[1008], batch=[1008], ptr=[17])
# DataBatch(x=[927, 512], edge_index=[2, 911], edge_type=[911], n1_mask=[927], n2_mask=[927], batch=[927], ptr=[17])
# DataBatch(x=[868, 512], edge_index=[2, 852], edge_type=[852], n1_mask=[868], n2_mask=[868], batch=[868], ptr=[17])
# DataBatch(x=[855, 512], edge_index=[2, 839], edge_type=[839], n1_mask=[855], n2_mask=[855], batch=[855], ptr=[17])
# DataBatch(x=[1104, 512], edge_index=[2, 1088], edge_type=[1088], n1_mask=[1104], n2_mask=[1104], batch=[1104], ptr=[17])
# DataBatch(x=[588, 512], edge_index=[2, 572], edge_type=[572], n1_mask=[588], n2_mask=[588], batch=[588], ptr=[17])
# DataBatch(x=[794, 512], edge_index=[2, 778], edge_type=[778], n1_mask=[794], n2_mask=[794], batch=[794], ptr=[17])
# DataBatch(x=[686, 512], edge_index=[2, 670], edge_type=[670], n1_mask=[686], n2_mask=[686], batch=[686], ptr=[17])
# DataBatch(x=[1296, 512], edge_index=[2, 1280], edge_type=[1280], n1_mask=[1296], n2_mask=[1296], batch=[1296], ptr=[17])
# DataBatch(x=[1278, 512], edge_index=[2, 1262], edge_type=[1262], n1_mask=[1278], n2_mask=[1278], batch=[1278], ptr=[17])
# DataBatch(x=[670, 512], edge_index=[2, 654], edge_type=[654], n1_mask=[670], n2_mask=[670], batch=[670], ptr=[17])
# DataBatch(x=[751, 512], edge_index=[2, 735], edge_type=[735], n1_mask=[751], n2_mask=[751], batch=[751], ptr=[17])
# DataBatch(x=[616, 512], edge_index=[2, 600], edge_type=[600], n1_mask=[616], n2_mask=[616], batch=[616], ptr=[17])
# DataBatch(x=[774, 512], edge_index=[2, 758], edge_type=[758], n1_mask=[774], n2_mask=[774], batch=[774], ptr=[17])
# DataBatch(x=[931, 512], edge_index=[2, 915], edge_type=[915], n1_mask=[931], n2_mask=[931], batch=[931], ptr=[17])
# DataBatch(x=[1276, 512], edge_index=[2, 1260], edge_type=[1260], n1_mask=[1276], n2_mask=[1276], batch=[1276], ptr=[17])
# DataBatch(x=[614, 512], edge_index=[2, 598], edge_type=[598], n1_mask=[614], n2_mask=[614], batch=[614], ptr=[17])
# DataBatch(x=[930, 512], edge_index=[2, 914], edge_type=[914], n1_mask=[930], n2_mask=[930], batch=[930], ptr=[17])
# DataBatch(x=[664, 512], edge_index=[2, 648], edge_type=[648], n1_mask=[664], n2_mask=[664], batch=[664], ptr=[17])
# DataBatch(x=[596, 512], edge_index=[2, 580], edge_type=[580], n1_mask=[596], n2_mask=[596], batch=[596], ptr=[17])
# DataBatch(x=[1384, 512], edge_index=[2, 1368], edge_type=[1368], n1_mask=[1384], n2_mask=[1384], batch=[1384], ptr=[17])
# DataBatch(x=[1488, 512], edge_index=[2, 1472], edge_type=[1472], n1_mask=[1488], n2_mask=[1488], batch=[1488], ptr=[17])
# DataBatch(x=[1168, 512], edge_index=[2, 1152], edge_type=[1152], n1_mask=[1168], n2_mask=[1168], batch=[1168], ptr=[17])
# DataBatch(x=[880, 512], edge_index=[2, 864], edge_type=[864], n1_mask=[880], n2_mask=[880], batch=[880], ptr=[17])
# DataBatch(x=[1040, 512], edge_index=[2, 1024], edge_type=[1024], n1_mask=[1040], n2_mask=[1040], batch=[1040], ptr=[17])
# DataBatch(x=[675, 512], edge_index=[2, 659], edge_type=[659], n1_mask=[675], n2_mask=[675], batch=[675], ptr=[17])
# DataBatch(x=[654, 512], edge_index=[2, 638], edge_type=[638], n1_mask=[654], n2_mask=[654], batch=[654], ptr=[17])
# DataBatch(x=[720, 512], edge_index=[2, 704], edge_type=[704], n1_mask=[720], n2_mask=[720], batch=[720], ptr=[17])
# DataBatch(x=[768, 512], edge_index=[2, 752], edge_type=[752], n1_mask=[768], n2_mask=[768], batch=[768], ptr=[17])
# DataBatch(x=[1488, 512], edge_index=[2, 1472], edge_type=[1472], n1_mask=[1488], n2_mask=[1488], batch=[1488], ptr=[17])
# DataBatch(x=[1440, 512], edge_index=[2, 1424], edge_type=[1424], n1_mask=[1440], n2_mask=[1440], batch=[1440], ptr=[17])
# DataBatch(x=[944, 512], edge_index=[2, 928], edge_type=[928], n1_mask=[944], n2_mask=[944], batch=[944], ptr=[17])
# DataBatch(x=[502, 512], edge_index=[2, 486], edge_type=[486], n1_mask=[502], n2_mask=[502], batch=[502], ptr=[17])
# DataBatch(x=[519, 512], edge_index=[2, 503], edge_type=[503], n1_mask=[519], n2_mask=[519], batch=[519], ptr=[17])
# DataBatch(x=[1868, 512], edge_index=[2, 1852], edge_type=[1852], n1_mask=[1868], n2_mask=[1868], batch=[1868], ptr=[17])
# DataBatch(x=[2336, 512], edge_index=[2, 2320], edge_type=[2320], n1_mask=[2336], n2_mask=[2336], batch=[2336], ptr=[17])
# DataBatch(x=[2336, 512], edge_index=[2, 2320], edge_type=[2320], n1_mask=[2336], n2_mask=[2336], batch=[2336], ptr=[17])
# DataBatch(x=[1571, 512], edge_index=[2, 1555], edge_type=[1555], n1_mask=[1571], n2_mask=[1571], batch=[1571], ptr=[17])
# DataBatch(x=[595, 512], edge_index=[2, 580], edge_type=[580], n1_mask=[595], n2_mask=[595], batch=[595], ptr=[16])

# %%
precision, recall, f1, support = precision_recall_fscore_support(y_true, y_pred, average="macro")
precision, recall, f1, support
# Out:
# /home/ubuntu/.conda/envs/amr/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.6311509707651913, 0.5109942515561031, 0.5199184395532496, None)
